# %% [markdown]
# ## 한글 형태소 분석 ,시각화, 워드 클라우드 등.
# ### 형태소 분석, 품사 태깅.
# ### 데이터 : 샘플 데이터 , 페이스북 전자 신문에서 크롤링 한 임시 데이터로  대체
# ### 설치 가 조금 복잡함.
# ### 1) jdk 17 이상 2) JPype(자바, 파이썬 연결하는 도구) 3) konlpy 패키지 설치.
#
# ## 주의사항, JPype 버전 1.4,  파이썬 버전 3.10.7 다운그레이드
# ## 시스템 환경 변수 , ex) JAVA_HOME : 경로 추가 하기. jdk 17
# ### 변수명 : JAVA_HOME (동일하게)
# ### 시스템 환경 변수의 경로 값 예제: C:\Program Files\Java\jdk-17
# ### 변수명 : Path
# ### 경로 : C:\Program Files\Java\jdk-17\bin
#
# ## 파이썬 3.10.x , 예) 3.10.7 버전으로 다운 받기.
# ### 시스템 환경 변수 추가 작업
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\Scripts
#
# ### cmd -> python -V
#
# ## 2) JPype(자바, 파이썬 연결하는 도구)
# ### 다운로드 사이트 주소 : https://github.com/jpype-project/jpype/releases
# ### JPype 검색하고, 버전은 JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl 받아서,
# ### 해당 다운로드 받은 폴더 이동하고, 해당 폴더 검색경로에서, cmd 실행하고,
# ### cmd -> pip install JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl
# ### 업그레이드 경고창 뜨면 :
# ### python.exe -m pip install --upgrade pip
# ### 업그레이드 후 , 다시 설치
# ### pip install JPype1‑1.4.0‑cp310‑cp310‑win_amd64.whl
# ### , 명령어 붙여넣기.
# ### pip install konlpy
#
# ### 코드 실행시, 설치한(다운그레이드한 버전, 3.10.7) 선택,
# ### 해당 쥬피터 노트북 관련 커널 설치도 자동으로 함.

# %% [markdown]
# # 용어 정리
# ## 형태소 , 형태소 분석
# ### 형태소: 언어에서 의미가 가장 작은 단위.
# ### 형태소 분석: 형태소, 어근, 접두사/접미사, 품사 등 다양한 속성 구조.
# ### 품사 태깅 예) 상용 이가 좋아 하는 음식 은 국밥 이다.
# ### 음식 : NNG, 이가/JKM , 좋아하는/VV, 이다/EFN , 높임말 : 하신다 -> 신/EPH
# ### 품사 태깅 해주는 패키지 : Hananum, Kkma, Komoran, Okt(Twitter 제공)
# ### Okt , 명사 /Noun , 에/ Josa, 먹는/ Verb , 다/Eomi

# %% [markdown]
# # 샘플 데이터 사용.
# #

# %%
# 최초 실행 때는, 설치 후에 주석하기.
# !pip install matplotlib
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\roaming\python\python310\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\admin\appdata\roaming\python\python310\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from wordcloud) (2.2.3)
# Requirement already satisfied: pillow in c:\users\admin\appdata\roaming\python\python310\site-packages (from wordcloud) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\admin\appdata\roaming\python\python310\site-packages (from wordcloud) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
import json
import re 
# Okt , 한글 품사 태깅하기위한 모듈, 도구.
from konlpy.tag import Okt
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
from wordcloud import WordCloud

# %%
# 샘플 데이터 읽어서, 메모리에서 확인해보기. 
# inputFileName = "./etnews.kr_facebook_2016-01-01_2018-08-01_4차 산업혁명.json"
inputFileName = "./취업_naver_news.json"
data = json.loads(open(inputFileName,"r",encoding = "utf-8").read())
data
# Out:
# [{'cnt': 1,
#   'description': '경기도에서 한식당을 운영하는 외식업주의 자녀 최 모 양은 &quot;우아한 사장님 자녀 장학금 덕분에 무리한 아르바이트 없이 <b>취업</b> 준비에 전념할 수 있었고 원하는 결과를 이룰 수 있었다&quot;며 소감을 전했다. 기존에는... ',
#   'link': 'https://www.ziksir.com/news/articleView.html?idxno=83406',
#   'org_link': 'https://www.ziksir.com/news/articleView.html?idxno=83406',
#   'pDate': '2025-02-27 17:06:00',
#   'title': '배달의민족, 외식업주 자녀에 최대 400만원 장학금 지원'},
#  {'cnt': 2,
#   'description': '경기도에서 한식당을 운영하는 외식업주의 자녀 최 모 양은 &quot;우아한 사장님 자녀 장학금 덕분에 무리한 아르바이트 없이 <b>취업</b> 준비에 전념할 수 있었고 원하는 결과를 이룰 수 있었다&quot;며 소감을 전했다. 기존에는... ',
#   'link': 'http://www.sportsq.co.kr/news/articleView.html?idxno=477355',
#   'org_link': 'http://www.sportsq.co.kr/news/articleView.html?idxno=477355',
#   'pDate': '2025-02-27 17:06:00',
#   'title': '배민, 외식업주 자녀 장학생 모집'},
#  {'cnt': 3,
#   'description': '노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양, 간호, 호스피스 등을 위한 간호조무사를 양성하고 있다. 이... ',
#   'link': 'http://sjbnews.com/news/news.php?number=842570',
#   'org_link': 'http://sjbnews.com/news/news.php?number=842570',
#   'pDate': '2025-02-27 17:06:00',
#   'title': '부영그룹 이중근 회장, 저출산고령사회위원회 감사패 수상'},
#  {'cnt': 4,
#   'description': '경남 김해 지역의 청년 고용률 향상에 이바지하는 한편, 젊은 세대의 <b>취업</b> 안정과 경제 활동에 기여할 것으로 예상된다. 지역 소상공인 제품 매입 확대를 통한 지역 경제 활성화 효과도 기대된다. 쿠팡은 지역 소상공인... ',
#   'link': 'http://www.sportsq.co.kr/news/articleView.html?idxno=477356',
#   'org_link': 'http://www.sportsq.co.kr/news/articleView.html?idxno=477356',
#   'pDate': '2025-02-27 17:06:00',
#   'title': '쿠팡, 김해 스마트물류센터 구축... 1930억 투자'},
#  {'cnt': 5,
#   'description': "또 외국인 유학생만을 위한 <b>취업</b>박람회도 개최하고 유학생의 안정적 생활과 지역사회와의 유대감 강화 및 정착을 돕는 유학생 후견인 시스템인 'K-가디언 제도'를 운영하고 있다. 유학생이 아닌 결혼이민자들을 위한... ",
#   'link': 'https://www.ccdailynews.com/news/articleView.html?idxno=2327667',
#   'org_link': 'https://www.ccdailynews.com/news/articleView.html?idxno=2327667',
#   'pDate': '2025-02-27 17:06:00',
#   'title': "[창간 79주년 특집] '소멸 위험 진입' 충북의 생존 전략은?"},
#  {'cnt': 6,
#   'description': '이같은 선발계획은 기존 몽골, 베트남 등에서 유입된 이주배경 학생들에게 보다 체계적인 직업교육의 기회를 제공하며, 안정적인 교육과 <b>취업</b>을 통해 미래를 설계할 수 있도록 지원한다는 뜻을 담고 있다. 특히, 이주배경... ',
#   'link': 'https://www.pinpointnews.co.kr/news/articleView.html?idxno=324536',
#   'org_link': 'https://www.pinpointnews.co.kr/news/articleView.html?idxno=324536',
#   'pDate': '2025-02-27 17:06:00',
#   'title': '전남교육청, 전남국제직업고에 해외 인재 70% 모집'},
#  {'cnt': 7,
#   'description': '또한, 국민은행은 교육생들에게 ▲자기주도학습비 지원 ▲1대1 <b>취업</b> 컨설팅 및 특강 ▲현직자와 함께하는 금융 프로젝트 및 <b>취업</b> 멘토링 ▲코딩테스트 대비반 운영 ▲국내 연수 및 힐링캠프 ▲<b>취업</b>준비패키지... ',
#   'link': 'https://www.cnbnews.com/news/article.html?no=710015',
#   'org_link': 'https://www.cnbnews.com/news/article.html?no=710015',
#   'pDate': '2025-02-27 17:06:00',
#   'title': "국민은행, 청년 인재 양성 ‘KB IT's Your Life’ 6기 발대식 가져"},
#  {'cnt': 8,
#   'description': "전문인력양성사업(<b>취업</b>연계형 특성화과정)'에 2년 연속 선정되는 쾌거를 이뤘다. 이 사업은... 이 사업을 통해 대학원생들에게 장학금 혜택과 함께 지역 기업들과의 <b>취업</b>연계 프로그램을 운영해 왔다. 특히 지난해에는... ",
#   'link': 'http://www.domin.co.kr/news/articleView.html?idxno=1504201',
#   'org_link': 'http://www.domin.co.kr/news/articleView.html?idxno=1504201',
#   'pDate': '2025-02-27 17:04:00',
#   'title': "우석대학교, 전북테크노파크 지원사업 2년 연속 선정 '쾌거'"},
#  {'cnt': 9,
#   'description': '◇《2024 주요노동판례》 개별적 근로관계(근로자성, 근로시간, 임금, 징계 및 해고, <b>취업</b>규칙 등)와 집단적 노사관계(공정대표의무, 노동조합, 노조법상 근로자, 단체교섭 및 단체협약, 부당노동행위 등), 비정규직... ',
#   'link': 'http://www.legaltimes.co.kr/news/articleView.html?idxno=84775',
#   'org_link': 'http://www.legaltimes.co.kr/news/articleView.html?idxno=84775',
#   'pDate': '2025-02-27 17:04:00',
#   'title': '[로펌 iN] 율촌, 《2024 주요노동판례》 판례집 발간'},
#  {'cnt': 10,
#   'description': '노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양, 간호, 호스피스 등을 위한 간호조무사를 양성하고 있다. 이... ',
#   'link': 'https://www.bigtanews.co.kr/article/view/big202502270027',
#   'org_link': 'https://www.bigtanews.co.kr/article/view/big202502270027',
#   'pDate': '2025-02-27 17:04:00',
#   'title': '부영그룹 이중근 회장, 저고위로부터 감사패 수상'},
#  {'cnt': 11,
#   'description': '이 밖에도 노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양, 간호, 호스피스 등을 위한 간호조무사를 양성하고 있다.... ',
#   'link': 'https://www.cnbnews.com/news/article.html?no=709904',
#   'org_link': 'https://www.cnbnews.com/news/article.html?no=709904',
#   'pDate': '2025-02-27 17:04:00',
#   'title': '이중근 부영그룹 회장, 저고위로부터 감사패 받아'},
#  {'cnt': 12,
#   'description': '우선 신규 인력 유입과 관련해 고용부는 청년과 여성, 중장년을 대상으로 한 맞춤형 <b>취업</b> 정보를 제공한다는 계획이다. 현재 건설업 <b>취업</b>자 절반 이상인 55.2%가 50세 이상을 기록하는 등 고령화로 인해 신규 인력 투입이... ',
#   'link': 'https://biz.chosun.com/topics/topics_social/2025/02/27/IVRKZH34CVGFTFI3BZUSW5DJC4/?utm_source=naver&utm_medium=original&utm_campaign=biz',
#   'org_link': 'https://biz.chosun.com/topics/topics_social/2025/02/27/IVRKZH34CVGFTFI3BZUSW5DJC4/?utm_source=naver&utm_medium=original&utm_campaign=biz',
#   'pDate': '2025-02-27 17:03:00',
#   'title': '고용부, 건설업 인력 고령화에 청년·여성 유입 지원 확대 추진'},
#  {'cnt': 13,
#   'description': '기아자동차 광주공장에서 또 다시 <b>취업</b>을 미끼로 한 사기 의혹이 불거졌다. 오랜 경기침체로 많은 기업들이 투자를 줄이면서 구직시장이 갈수록 줄어드는 상황에서 구직자의 절박한 심정을 악용하는 <b>취업</b>사기는... ',
#   'link': 'http://www.jnilbo.com/76271942495',
#   'org_link': 'http://www.jnilbo.com/76271942495',
#   'pDate': '2025-02-27 17:03:00',
#   'title': '사설&gt;고객 신뢰 무너뜨리는 기아車 <b>취업</b>사기'},
#  {'cnt': 14,
#   'description': '한수원은 초록우산 어린이재단과 협업을 통해 자립준비청년들이 성공적으로 사회에 정착할 수 있도록 기초학습, 인턴십, 자립수당, <b>취업</b>축하금 및 <b>취업</b>지원비 등 자립 단계에 맞는 맞춤형 프로그램을 지원하고 있다. 이... ',
#   'link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786256',
#   'org_link': 'https://www.newsworks.co.kr/news/articleView.html?idxno=786256',
#   'pDate': '2025-02-27 17:02:00',
#   'title': "한수원 '열여덟 혼자서기' 인턴십 기관 현판 전달"},
#  {'cnt': 15,
#   'description': '선관위, 대규모 <b>취업</b> 청탁…&quot;고위직 자녀 공무원에 채용&quot; 선거관리위원회가 지난 10여 년 동안 고위직 인사의 자녀를 비공개 채용하거나 면접 점수를 위조하며 채용 비리에 나섰던 사실이 감사원 감사 결과 드러났습니다.... ',
#   'link': 'http://mbn.mk.co.kr/pages/news/newsView.php?category=mbn00006&news_seq_no=5097083',
#   'org_link': 'http://mbn.mk.co.kr/pages/news/newsView.php?category=mbn00006&news_seq_no=5097083',
#   'pDate': '2025-02-27 17:02:00',
#   'title': '이재명-임종석 만났다…&quot;이재명, 더 잘해주길&quot; [짤e몽땅]'},
#  {'cnt': 16,
#   'description': '경남 김해 지역의 청년 고용률 향상에 이바지하는 한편, 젊은 세대의 <b>취업</b> 안정과 경제 활동에 기여할 것으로 예상된다. 지역 소상공인 제품 매입 확대를 통한 지역 경제 활성화 효과도 기대된다. 쿠팡은 지역 소상공인... ',
#   'link': 'http://www.smedaily.co.kr/news/articleView.html?idxno=318586',
#   'org_link': 'http://www.smedaily.co.kr/news/articleView.html?idxno=318586',
#   'pDate': '2025-02-27 17:02:00',
#   'title': '쿠팡, 김해물류센터 구축에 1930억 투자…경남 최남단도 새벽배송'},
#  {'cnt': 17,
#   'description': '<b>취업</b>은 본인이 하는 것이지만 혼자하기에는 외롭고, 고단하고, 스트레스를 많이 받는다. 경제적으로도 힘들고... 5년이상 복무한 제대군인은 전역일 상관없이 제대군인지원센터에서 <b>취업</b>을 위한 도움을 받기를 바란다.... ',
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=676624',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=676624',
#   'pDate': '2025-02-27 17:02:00',
#   'title': '[기고] 제대군인, 민간기업에 성공적인 입사를 위한 마음가짐'},
#  {'cnt': 18,
#   'description': '관련 <b>취업</b>자도 급감하고 있다. 공제회는 지난달 건설업 <b>취업</b>자가 192만1,000명으로, 전년 동월 대비 8.1%나 준 것으로 추산했다. 이 중 사무·판매 직무 등을 제외한 건설 현장 육체노동 종사자(기능원·장치기계조작 및... ',
#   'link': 'https://www.hankookilbo.com/News/Read/A2025022711170005410?did=NA',
#   'org_link': 'https://www.hankookilbo.com/News/Read/A2025022711170005410?did=NA',
#   'pDate': '2025-02-27 17:00:00',
#   'title': '롯데건설 1조 자산매각, 중견 건설사는 줄줄이 법정관리...얼어붙는 건설...'},
#  {'cnt': 19,
#   'description': '향상시키고 <b>취업</b> 경쟁력을 높이기 위해 2022년부터 지속적으로 운영되고 있다. 특히 고용노동부가... KB국민은행은 참가자들에게 ▲자기주도학습비 지원 ▲1대1 <b>취업</b> 컨설팅 및 특강 ▲금융권 현직자와... ',
#   'link': 'https://www.mhns.co.kr/news/articleView.html?idxno=710709',
#   'org_link': 'https://www.mhns.co.kr/news/articleView.html?idxno=710709',
#   'pDate': '2025-02-27 17:00:00',
#   'title': "KB국민은행, 'KB IT's Your Life' 6기 발대식 개최"},
#  {'cnt': 20,
#   'description': '한국마사회는 지난해 8월, 청년들에게 양질의 일자리 제공과 <b>취업</b> 실무 역량을 배양하기 위해 35명을... 청년들의 <b>취업</b> 역량 개발과 실무적 이해도 향상에 도움이 될 수 있도록 노력하겠다&quot;고 밝혔다. 한국마사회는... ',
#   'link': 'http://www.newsian.co.kr/news/articleView.html?idxno=77345',
#   'org_link': 'http://www.newsian.co.kr/news/articleView.html?idxno=77345',
#   'pDate': '2025-02-27 17:00:00',
#   'title': "한국마사회, 2024년 체험형 청년인턴 수료식...'꿈을 향한 첫걸음 딛다'"},
#  {'cnt': 21,
#   'description': '맞춤형 <b>취업</b> 성과 돋보여 전라남도교육청 소속 직업계고와 마이스터고 졸업(예정)생 800여 명이 2024년도 공공기관, 대기업, 금융기관, 공무원 등 주요 기관 및 기업에 <b>취업</b>한 것으로 집계됐다. 27일 전라남도교육청... ',
#   'link': 'https://www.cnbnews.com/news/article.html?no=709995',
#   'org_link': 'https://www.cnbnews.com/news/article.html?no=709995',
#   'pDate': '2025-02-27 17:00:00',
#   'title': '전남 직업계고 학생, 공공기관대기업 등 대거 ‘합격’'},
#  {'cnt': 22,
#   'description': '이 사업은 <b>취업</b>과 창업을 준비하는 청년과 중소기업 근로자를 위한 맞춤형 주거 공간으로, <b>취업</b>지원 라운지와 공유 오피스 등 특화시설이 함께 조성될 예정이다. 2026년 착공, 2029년 준공을 목표로 추진된다. 또한... ',
#   'link': 'https://www.joongdo.co.kr/web/view.php?key=20250227010008942',
#   'org_link': 'https://www.joongdo.co.kr/web/view.php?key=20250227010008942',
#   'pDate': '2025-02-27 17:00:00',
#   'title': "대전시, 청년주택 2만호 공급 '착착'"},
#  {'cnt': 23,
#   'description': '이번 사업 선정으로 평택대학교는 졸업 후 2년 이내 미<b>취업</b>자·지역 내 미<b>취업</b> 청년을 대상으로 맞춤형 <b>취업</b> 지원을 제공하게 된다. 취창업지원단을 중심으로 구직자의 노동시장 진입을 돕고, 지역 기업과의 협력... ',
#   'link': 'http://www.inews24.com/view/1818571',
#   'org_link': 'http://www.inews24.com/view/1818571',
#   'pDate': '2025-02-27 16:59:00',
#   'title': '평택대, 고용노동부 ‘졸업생 특화 프로그램 사업’ 선정'},
#  {'cnt': 24,
#   'description': "해외<b>취업</b> 및 이민 설명회'를 온라인 화상회의 플랫폼(ZOOM)을 통해 개최했다. 이번 설명회는 제대군인의 해외 <b>취업</b>·이민 기회를 확대하기 위한 목적으로 기획됐다. 캐나다 각 주별 비자 제도와 <b>취업</b> 가능 직종, 이민 절차... ",
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=676620',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=676620',
#   'pDate': '2025-02-27 16:58:00',
#   'title': "서울제대군인지원센터 '캐나다 해외<b>취업</b>·이민 설명회' 개최"},
#  {'cnt': 25,
#   'description': '또 A 씨에게 가정폭력 치료프로그램 40시간 이수와 아동학대 치료프로그램 40시간 이수, 아동 관련 기관 5년간 <b>취업</b>제한도 명령했다. A 씨는 2019년 4월부터 지난해 8월까지 경남 김해시 주촌면 주거지 등에서 아내 B 씨... ',
#   'link': 'https://www.news1.kr/local/busan-gyeongnam/5704099',
#   'org_link': 'https://www.news1.kr/local/busan-gyeongnam/5704099',
#   'pDate': '2025-02-27 16:58:00',
#   'title': '&quot;강압적 통제해야&quot; 자녀들 앞에서 아내 상습 폭행 40대 징역 4년'},
#  {'cnt': 26,
#   'description': "HD현대1%나눔재단(이사장 권오갑)이 화가를 꿈꾸는 장애인들의 성장을 돕고 있다. HD현대1%나눔재단은 권오갑 이사장을 비롯한 재단 이사진이 27일 서울 강동구에 위치한 대한사회복지회 '마스터피스제작소' 사업장을... ",
#   'link': 'https://www.newspim.com/news/view/20250227000904',
#   'org_link': 'https://www.newspim.com/news/view/20250227000904',
#   'pDate': '2025-02-27 16:57:00',
#   'title': 'HD현대1%나눔재단, 장애인 화가의 꿈 실현 위한 다양한 지원'},
#  {'cnt': 27,
#   'description': "<b>취업</b> 후 상환하는 학자금대출의 금리 상한을 매 학기 시작 전 국채 3년간 평균 수익률 120%에서 110%로 조정하는 내용의 '<b>취업</b> 후 학자금 상환 특별법'도 본회의 문턱을 넘었습니다. 대학교원 신규 채용 시 임용권자가... ",
#   'link': 'http://www.yonhapnewstv.co.kr/AKR20250227165700509',
#   'org_link': 'http://www.yonhapnewstv.co.kr/AKR20250227165700509',
#   'pDate': '2025-02-27 16:57:00',
#   'title': '&quot;교육감이 교원 정신건강 관리&quot;…법안 국회 본회의 통과'},
#  {'cnt': 28,
#   'description': '◆조선업 신규 <b>취업</b>자 이주 정착비 지원 거제시가 조선업 신규 <b>취업</b>자에게 이주 정착비를 월 30만원씩 최대 1년간 지원한다. 지원 대상은 조선업체에 신규 <b>취업</b>한 근로자로, 지난 2023년 1월1일 이후 경남 외 지역에서... ',
#   'link': 'https://www.newsfreezone.co.kr/news/articleView.html?idxno=611581',
#   'org_link': 'https://www.newsfreezone.co.kr/news/articleView.html?idxno=611581',
#   'pDate': '2025-02-27 16:56:00',
#   'title': "거제시, 지방재정 신속집행 6년 연속 '우수'...특별조정교부금 1억원 확..."},
#  {'cnt': 29,
#   'description': '사진=리멤버앤컴퍼니 이번 캠페인은 장기화된 <b>취업</b>난 속에 지친 <b>취업</b>준비생들의 상반기 신입 공채 최종 합격에 실질적인 도움을 주고자 마련됐다. 자소설닷컴이 취준생들의 서류·인적성·면접 등 채용 전형에 어려운... ',
#   'link': 'https://www.slist.kr/news/articleView.html?idxno=622928',
#   'org_link': 'https://www.slist.kr/news/articleView.html?idxno=622928',
#   'pDate': '2025-02-27 16:56:00',
#   'title': "자소설닷컴, '2025 상반기 합격로드' 캠페인 진행"},
#  {'cnt': 30,
#   'description': '간호조무사 <b>취업</b> 허용 제안 [아시아타임즈=이재성 기자] 이중근 부영그룹 회장이 저출산... 노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은 현재 라오스와 캄보디아 등 동남아에... ',
#   'link': 'https://www.asiatime.co.kr/article/20250227500388',
#   'org_link': 'https://www.asiatime.co.kr/article/20250227500388',
#   'pDate': '2025-02-27 16:56:00',
#   'title': '이중근 부영그룹 회장, 저출산고령위 감사패 받아'},
#  {'cnt': 31,
#   'description': "<b>취업</b> 후 상환하는 학자금대출의 금리 상한을 매 학기 시작 전 국채 3년간 평균 수익률의 120%에서 110%로 조정하는 내용의 '<b>취업</b> 후 학자금 상환 특별법'도 국회 본회의를 통과했다. 또한 아동·청소년 성착취물 등은 유포... ",
#   'link': 'https://view.asiae.co.kr/article/2025022716552381889',
#   'org_link': 'https://view.asiae.co.kr/article/2025022716552381889',
#   'pDate': '2025-02-27 16:55:00',
#   'title': '교원 정신건강 증진사업 의무화 법안, 국회 본회의 통과'},
#  {'cnt': 32,
#   'description': "서산나래(원장 박정은)에서 주관하는 '발달장애인 재능키움사업'은 지난 2021년부터 공사의 후원으로 운영되고 있으며, 현재까지 총 82명의 제과제빵사를 양성하고, 이 중 16명이 <b>취업</b>에 성공해 발달장애인의 직업 역량을... ",
#   'link': 'http://www.koreareport.co.kr/news/articleView.html?idxno=32998',
#   'org_link': 'http://www.koreareport.co.kr/news/articleView.html?idxno=32998',
#   'pDate': '2025-02-27 16:54:00',
#   'title': "여수광양항만공사, 발달장애인 재능키움사업 '어서와, 로스팅은 처음이..."},
#  {'cnt': 33,
#   'description': '<b>취업</b> 정보를 제공했다. 그 결과 4년 연속 우수사례로 선정됐으며 총 6명의 금융감독원장 표창자를 배출했다. 강재훈 JT저축은행 감사팀장은 1사1교 금융교육 강사로 자발적으로 참여해 사회초년생과 금융사 <b>취업</b>... ',
#   'link': 'https://biz.heraldcorp.com/article/10430567?ref=naver',
#   'org_link': 'https://biz.heraldcorp.com/article/10430567?ref=naver',
#   'pDate': '2025-02-27 16:54:00',
#   'title': 'JT저축은행, 1사1교 금융교육 우수사례 선정…금감원장 표창 수상'},
#  {'cnt': 34,
#   'description': 'JT저축은행은 지난 2017년부터 지역 내 특성화고교인 분당경영고와 1사1교 금융교육 자매결연을 맺고 8년간 학생들에게 금융 지식 교육과 금융권 <b>취업</b> 정보를 제공했다. 직원들의 자발적인 교육 봉사 참여와 함께 동문... ',
#   'link': 'http://www.inews24.com/view/1818587',
#   'org_link': 'http://www.inews24.com/view/1818587',
#   'pDate': '2025-02-27 16:54:00',
#   'title': 'JT저축은행, 4년 연속 1사1교 금융교육 우수사례 선정'},
#  {'cnt': 35,
#   'description': "대학생의 학자금 대출 부담을 완화하기 위한 '<b>취업</b> 후 학자금 상환 특별법' 개정안도 통과됐다. 금리 상한을 매 학기 시작 전 3년간 국채 평균수익률의 120%에서 11%로 낮췄다. 연체금 총한도도 미납한 대출원리금의 9%에서 5... ",
#   'link': 'https://www.newspim.com/news/view/20250227000248',
#   'org_link': 'https://www.newspim.com/news/view/20250227000248',
#   'pDate': '2025-02-27 16:53:00',
#   'title': "온라인으로만 수업 받아도 학점 받는 '온라인학교' 문 연다"},
#  {'cnt': 36,
#   'description': '요양원이 아닌 가정에서 가족과 함께 임종할 수 있도록 간병인과 도우미 지원을 확대하고 외국인 간호조무사 국내 <b>취업</b> 허용을 추진해야 한다고 주장했다. 이와 함께 인구 문제를 종합적으로 관리할 ‘인구부’... ',
#   'link': 'https://view.asiae.co.kr/article/2025022711223060569',
#   'org_link': 'https://view.asiae.co.kr/article/2025022711223060569',
#   'pDate': '2025-02-27 16:53:00',
#   'title': "'아이 낳으면 1억' 이중근 부영 회장, 저출산위 감사패 받아"},
#  {'cnt': 37,
#   'description': '관내 약 20개 항만·물류 기업과 협력해 기업 현장 전문가와 공동 교육과정을 개발·운영하고 인턴십 후속 관리 프로그램을 통해 학생들의 <b>취업</b> 연계까지 지원할 계획이다. ◆2025년도 창원시체육회 정기총회 개최... ',
#   'link': 'https://www.kukinews.com/article/view/kuk202502270204',
#   'org_link': 'https://www.kukinews.com/article/view/kuk202502270204',
#   'pDate': '2025-02-27 16:52:00',
#   'title': '창원대·경남대, 해운항만물류 전문인력 양성사업 수행기관 선정'},
#  {'cnt': 38,
#   'description': '이 사업은 <b>취업</b>과 창업을 준비하는 청년과 중소기업 근로자를 위한 맞춤형 주거 공간으로 <b>취업</b>지원 라운지와 공유 오피스 등 특화시설이 함께 조성될 예정이다. 2026년 착공 및 2029년 준공을 목표로 추진된다. 원도심... ',
#   'link': 'https://m.skyedaily.com/news_view.html?ID=264577',
#   'org_link': 'https://m.skyedaily.com/news_view.html?ID=264577',
#   'pDate': '2025-02-27 16:52:00',
#   'title': '‘대전형 청년주택’ 청년·신혼부부 주거 혁신 가속'},
#  {'cnt': 39,
#   'description': '서울시립대-육군 인사사령부, 전역(예정) 장교 <b>취업</b>지원 업무협약 체결/사진=서울시립대 제공 양 기관은 2월 27일 오후 3시, 서울시립대 대학본부 대회의실에서 <b>취업</b>역량 강화 및 맞춤형 <b>취업</b>연계 프로그램 운영을 위한... ',
#   'link': 'http://www.veritas-a.com/news/articleView.html?idxno=544103',
#   'org_link': 'http://www.veritas-a.com/news/articleView.html?idxno=544103',
#   'pDate': '2025-02-27 16:50:00',
#   'title': '서울시립대-육군 인사사령부, 전역(예정) 장교 <b>취업</b>지원 업무협약 체결'},
#  {'cnt': 40,
#   'description': '최근 5년간 <b>취업</b>난의 영향으로 사관학교의 경쟁률이 계속해서 상승하는 추세다. 강대식(국민의힘)... 사관학교의 경쟁률이 상승하고 자퇴생이 감소한 배경에는 가장 먼저 <b>취업</b>난이 꼽힌다. 경제 침체로... ',
#   'link': 'http://www.veritas-a.com/news/articleView.html?idxno=544045',
#   'org_link': 'http://www.veritas-a.com/news/articleView.html?idxno=544045',
#   'pDate': '2025-02-27 16:50:00',
#   'title': "2025사관학교 경쟁률 32.1대1 '상승'.. 국간사 38.7대1 '최고' 공사 육사..."},
#  {'cnt': 41,
#   'description': "울산시 중구는 미<b>취업</b> 청년들의 사회 진출을 돕는 '청년도전 지원사업'을 본격 추진한다고 27일 밝혔다. 청년도전 지원사업은 고용노동부 주관 공모사업으로, 미<b>취업</b> 청년들을 대상으로 자신감과 구직 의욕을 높이는... ",
#   'link': 'https://www.newsis.com/view/NISX20250227_0003081491',
#   'org_link': 'https://www.newsis.com/view/NISX20250227_0003081491',
#   'pDate': '2025-02-27 16:49:00',
#   'title': '울산 중구, 미<b>취업</b> 청년 120명 사회 진출 지원'},
#  {'cnt': 42,
#   'description': '경기도에서 한식당을 운영하는 외식업주의 자녀 최 모 양은 &quot;우아한 사장님 자녀 장학금 덕분에 무리한 아르바이트 없이 <b>취업</b> 준비에 전념할 수 있었고 원하는 결과를 이룰 수 있었다&quot;며 소감을 전했다. 기존에는... ',
#   'link': 'http://www.m-i.kr/news/articleView.html?idxno=1212372',
#   'org_link': 'http://www.m-i.kr/news/articleView.html?idxno=1212372',
#   'pDate': '2025-02-27 16:48:00',
#   'title': '배민, 외식업주 자녀에 최대 400만원 장학금 지원…배민 미입점도 가능'},
#  {'cnt': 43,
#   'description': '창원지역 20여개 항만·물류기업과 협력해 공동 교육과정을 개발·운영하고, 인턴십 후속 관리를 통해 학생들의 <b>취업</b>까지 지원할 계획이다. 시는 진해신항 및 부산항 신항 등 국제 물류인프라 건설이 활발히 진행되는... ',
#   'link': 'https://www.yna.co.kr/view/AKR20250227148300052?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250227148300052?input=1195m',
#   'pDate': '2025-02-27 16:47:00',
#   'title': '창원대·경남대, 해운항만물류 전문인력 양성…해수부 공모 선정'},
#  {'cnt': 44,
#   'description': '금융사 <b>취업</b> 준비생의 자산 형성을 위한 금융 노하우와 20여년 다양한 금융사 재직경험을 바탕으로 한 금융업종별 특징교육에서 좋은 평가를 받았다. 특히 예비 금융인을 준비하는 <b>취업</b> 준비생들을 대상으로 진행한... ',
#   'link': 'https://www.ceoscoredaily.com/page/view/2025022716400661651',
#   'org_link': 'https://www.ceoscoredaily.com/page/view/2025022716400661651',
#   'pDate': '2025-02-27 16:46:00',
#   'title': 'JT저축은행, 금융감독원 1사1교 금융교육 우수사례 선정'},
#  {'cnt': 45,
#   'description': '부산진구가 청년들의 <b>취업</b> 역량 강화를 위해 차별화된 원스톱 <b>취업</b>지원 사업을 진행한다. 부산진구는 청년 일자리카페 운영, 청년 자격시험 응시료지원, 기업탐방 프로그램 등을 통해 <b>취업</b> 준비부터 맞춤형 컨설팅까지... ',
#   'link': 'http://www.weeklytoday.com/news/articleView.html?idxno=681568',
#   'org_link': 'http://www.weeklytoday.com/news/articleView.html?idxno=681568',
#   'pDate': '2025-02-27 16:46:00',
#   'title': '[위클리오늘] 청년친화도시 부산진구, 청년 <b>취업</b> 활성화를 위한 다양한...'},
#  {'cnt': 46,
#   'description': '경복대학교 대학일자리플러스센터는 졸업생 대상 실질적인 <b>취업</b> 정보를 제공하는 행사를 성료했다고 27일 밝혔다. 이번 행사는 졸업생들에게 대학일자리플러스센터에서 제공하는 다양한 <b>취업</b>지원 프로그램을 소개하고... ',
#   'link': 'https://www.newsis.com/view/NISX20250227_0003081484',
#   'org_link': 'https://www.newsis.com/view/NISX20250227_0003081484',
#   'pDate': '2025-02-27 16:46:00',
#   'title': '[포천소식]경복대, 졸업생 <b>취업</b>지원 행사 성료 등'},
#  {'cnt': 47,
#   'description': '서울시립대와 육군 인사사령부가 27일 육군 단기복무 전역(예정) 장교들의 <b>취업</b>역량 강화 및 맞춤형 <b>취업</b>연계 프로그램 운영을 위한 업무협약을 체결했다. 사진=서울시립대 제공  서울시립대학교와 육군 인사사령부가... ',
#   'link': 'https://dhnews.co.kr/news/view/1065598931413752',
#   'org_link': 'https://dhnews.co.kr/news/view/1065598931413752',
#   'pDate': '2025-02-27 16:46:00',
#   'title': '서울시립대·육군 인사사령부, 전역(예정) 장교 <b>취업</b>지원 협약'},
#  {'cnt': 48,
#   'description': '대학생 청년 <b>취업</b>률이 45%다”라고 지적했다. 그는 “트럼프는 중국 60% 고관세, 한국 25% 관세를 부과한다.... 광운대 벤처스타트업아카데미 SW <b>취업</b> 캠프 개최 지난 17일부터 18일 열린 광운대학교 벤처스타트업아카데미 SW... ',
#   'link': 'https://www.asiatime.co.kr/article/20250227500386',
#   'org_link': 'https://www.asiatime.co.kr/article/20250227500386',
#   'pDate': '2025-02-27 16:46:00',
#   'title': '[27일 대학가] 삼육대·세종대·광운대'},
#  {'cnt': 49,
#   'description': '금융사 <b>취업</b> 준비생의 자산 형성을 위한 금융 노하우와 20여년 다양한 금융사 재직경험을 바탕으로 한 금융업종별 특징교육에서 좋은 평가를 받았다. 특히 예비 금융인을 준비하는 <b>취업</b> 준비생들을 대상으로 진행한... ',
#   'link': 'http://www.wikileaks-kr.org/news/articleView.html?idxno=164550',
#   'org_link': 'http://www.wikileaks-kr.org/news/articleView.html?idxno=164550',
#   'pDate': '2025-02-27 16:46:00',
#   'title': "JT저축은행, '1사1교 금융교육 우수사례' 금융감독원장 표창 수상"},
#  {'cnt': 50,
#   'description': "SBS ‘정글밥2-페루밥’ 캡처 이날 최현석은 &quot;극한 <b>취업</b> 다큐 정도로 봐주시면 될 것 같다&quot;며 &quot;분명 저에게는 미식 여행이라고 얘기했는데 '체험 정글의 현장' 이런 걸 찍은 것 같다&quot;고 <b>취업</b> 사기를 폭로해 웃음을 자아냈다.... ",
#   'link': 'http://www.segye.com/newsView/20250227515701?OutUrl=naver',
#   'org_link': 'http://www.segye.com/newsView/20250227515701?OutUrl=naver',
#   'pDate': '2025-02-27 16:45:00',
#   'title': '‘제작진 <b>취업</b> 사기→근로 조건 폭로’... 최현석 “분 안 풀린다”'},
#  {'cnt': 51,
#   'description': 'KT는 에이블스쿨 6기 교육생의 <b>취업</b> 지원을 위한 잡페어를 열었다. 에이블스쿨은 KT가 지난 2021년부터... KT는 에이블스쿨 교육생들의 <b>취업</b> 지원을 위해 전국 단위로 연 2회 잡페어를 열고 있다. 이번 잡페어에는... ',
#   'link': 'http://www.wsobi.com/news/articleView.html?idxno=270115',
#   'org_link': 'http://www.wsobi.com/news/articleView.html?idxno=270115',
#   'pDate': '2025-02-27 16:44:00',
#   'title': '통신 3사, 미래 먹거리 AI 인재 확보에 총력'},
#  {'cnt': 52,
#   'description': "청년층의 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 2022년부터 꾸준히 추진해 오고 있다. 특히... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이날 발대식에는 과거 'KB IT's Your Life'를 수료한 KB국민은행 재직 직원들의... ",
#   'link': 'https://www.lcnews.co.kr/news/articleView.html?idxno=95513',
#   'org_link': 'https://www.lcnews.co.kr/news/articleView.html?idxno=95513',
#   'pDate': '2025-02-27 16:44:00',
#   'title': "국민은행, 청년 IT 인재 양성 'KB IT's Your Life' 발대식 개최"},
#  {'cnt': 53,
#   'description': '또 올해 개최되는 ‘매월 성공<b>취업</b> 스마트매칭 <b>취업</b>박람회’ 등에서는 구인·구직자 지원을 위한 협력 사업을 확대해 실질적인 고용 지원이 이루어질 수 있도록 할 방침이다. 최순고 김천시장 권한대행(부시장)은 “이번... ',
#   'link': 'https://m.skyedaily.com/news_view.html?ID=264631',
#   'org_link': 'https://m.skyedaily.com/news_view.html?ID=264631',
#   'pDate': '2025-02-27 16:44:00',
#   'title': '김천시 일자리 거버넌스 출범'},
#  {'cnt': 54,
#   'description': "청년층 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 2022년부터 꾸준히 추진해 오고 있다. 고용노동부가... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이날 발대식에는 과거 'KB IT's Your Life'를 수료한 KB국민은행 재직... ",
#   'link': 'https://www.etnews.com/20250227000401',
#   'org_link': 'https://www.etnews.com/20250227000401',
#   'pDate': '2025-02-27 16:44:00',
#   'title': "청년 IT 인재 양성 프로그램 'KB IT's Your Life'6기 발대식 개최"},
#  {'cnt': 55,
#   'description': '하는 형틀목공, 철근공, 콘트리트공 등 3개 공사 종류에 E-7-3 인력 도입을 검토한다. 또 국적에 따라 이원화돼 있는 재외동포(F-4)와 방문<b>취업</b>(H-2) 비자를 통합해 H-2 비자로도 단순노무직종 <b>취업</b>을 허용하는 방안을 추진한다.',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04690406642074784',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04690406642074784',
#   'pDate': '2025-02-27 16:43:00',
#   'title': '정부, 건설공사비에 건설근로자 적정임금 반영 추진'},
#  {'cnt': 56,
#   'description': '배우 류수영, 최다니엘, 김옥빈, 이준, 셰프 최현석, 윤남노가  2월 27일(목) 오후, 서울시 양천구 목동 SBS 방송센터에서 열린 SBS 예능 ‘정글밥2 - 페루밥’ 제작발표회에 참석해 포토타임을 갖고 있다. SBS 예능... ',
#   'link': 'https://www.kgnews.co.kr/news/article.html?no=832910',
#   'org_link': 'https://www.kgnews.co.kr/news/article.html?no=832910',
#   'pDate': '2025-02-27 16:42:00',
#   'title': "[영상] 최다니엘-최현석-류수영-김옥빈-이준-윤남노, <b>취업</b>사기? '맛벌이..."},
#  {'cnt': 57,
#   'description': '◇ 체계적인 <b>취업</b> 지원과 높은 <b>취업</b>률 학생들의 <b>취업</b> 경쟁력을 높이기 위해 다양한 <b>취업</b> 지원 프로그램을 운영하고 있다. <b>취업</b>가이드북 제작, <b>취업</b> 멘토링, 실전 면접 클리닉 등 맞춤형 <b>취업</b> 지원책을 제공하며, 졸업생... ',
#   'link': 'https://dhnews.co.kr/news/view/1065598590125589',
#   'org_link': 'https://dhnews.co.kr/news/view/1065598590125589',
#   'pDate': '2025-02-27 16:40:00',
#   'title': '경복대 간호학과, 시대가 요구하는 전문 간호인력 양성'},
#  {'cnt': 58,
#   'description': "노동판례집은 노동 판결을 주제별로 모아 '개별적 근로관계(근로자성·근로시간·임금·징계 및 해고·<b>취업</b>규칙 등)'와 '집단적 노사관계(공정대표의무·노동조합·노동조합 및 노동관계조정법상 근로자·단체교섭 및... ",
#   'link': 'http://www.labortoday.co.kr/news/articleView.html?idxno=226501',
#   'org_link': 'http://www.labortoday.co.kr/news/articleView.html?idxno=226501',
#   'pDate': '2025-02-27 16:40:00',
#   'title': "법무법인 율촌 노동팀 '2024 주요노동판례' 발간"},
#  {'cnt': 59,
#   'description': '남편은 다니던 회사에서 퇴직한 후에 한 달 정도 지난 뒤에 같은 동종 업체에 <b>취업</b>하였다. 퇴직 전에 다니던... 그러다 다시 아시는 분 소개로 비슷한 동종 업체에 부사장으로 <b>취업</b>하게 되었다. 퇴직 전부터 알고 지내던... ',
#   'link': 'https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003106437&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news',
#   'org_link': 'https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003106437&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news',
#   'pDate': '2025-02-27 16:38:00',
#   'title': '주말엔 늘 누워만 있던 우리 남편이 달라졌어요'},
#  {'cnt': 60,
#   'description': "청년층의 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 지난 2022년부터 꾸준히 추진해 오고 있다. 특히... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이날 발대식에는 과거 'KB IT's Your Life'를 수료한 KB국민은행 재직... ",
#   'link': 'https://www.discoverynews.kr/news/articleView.html?idxno=1058870',
#   'org_link': 'https://www.discoverynews.kr/news/articleView.html?idxno=1058870',
#   'pDate': '2025-02-27 16:38:00',
#   'title': 'KB국민은행, 청년 IT 인재 양성 프로그램 6기 발대식 개최'},
#  {'cnt': 61,
#   'description': '사회초년생 및 금융사 <b>취업</b> 준비생의 자산 형성을 위한 금융 노하우와 20여년간 다양한 금융사 재직경험을 바탕으로 한 업종별 특징교육에서 좋은 평가를 받았다. 예비 금융인을 준비하는 <b>취업</b> 준비생들을 대상으로... ',
#   'link': 'http://www.seoulfn.com/news/articleView.html?idxno=549703',
#   'org_link': 'http://www.seoulfn.com/news/articleView.html?idxno=549703',
#   'pDate': '2025-02-27 16:37:00',
#   'title': "JT저축은행, 금감원 '1사1교 금융교육' 우수사례 선정"},
#  {'cnt': 62,
#   'description': '<b>취업</b> 여부를 점검한 결과, 위반자 총 33명을 적발했다고 27일 밝혔다. 아동복지법에 따르면 아동학대관련범죄로 형 또는 치료감호를 선고받아 확정된 사람은 일정 기간 아동관련기관을 운영하거나 해당 기관에 <b>취업</b>할... ',
#   'link': 'https://www.ibabynews.com/news/articleView.html?idxno=127185',
#   'org_link': 'https://www.ibabynews.com/news/articleView.html?idxno=127185',
#   'pDate': '2025-02-27 16:36:00',
#   'title': '아동학대했는데 유치원, 학교 근무? 전과자 33명 적발'},
#  {'cnt': 63,
#   'description': '통계청에 따르면 지난달 건설업 <b>취업</b>자 수는 약 192만1000명으로, 1년 전보다 16만8000명이 줄었다. 이는 2017년... 또, 청년, 여성 등 대상별로 <b>취업</b> 희망자를 발굴해 맞춤형 <b>취업</b>정보를 제공한다. 김문수 고용노동부 장관은... ',
#   'link': 'https://biz.heraldcorp.com/article/10430540?ref=naver',
#   'org_link': 'https://biz.heraldcorp.com/article/10430540?ref=naver',
#   'pDate': '2025-02-27 16:36:00',
#   'title': '정부, 건설업 ‘기능등급제’ 안착...“청년·여성도 근로여건 개선”'},
#  {'cnt': 64,
#   'description': '이외에도 이 회장은 사랑하는 가족들의 손을 잡고 임종할 수 있게 재가 간병인 및 도우미 등에 예산을 지원하는 재가 임종제도와 노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은... ',
#   'link': 'https://www.onews.tv/news/articleView.html?idxno=235901',
#   'org_link': 'https://www.onews.tv/news/articleView.html?idxno=235901',
#   'pDate': '2025-02-27 16:36:00',
#   'title': "부영그룹 이중근 회장, '저출생 추세 반전에 기여한 공로'로 저고위로부..."},
#  {'cnt': 65,
#   'description': '기아자동차 공장에 <b>취업</b> 시켜주겠다며 금품을 가로챘다는 신고가 잇달아 광주경찰청이 수사를 확대한다. 광주경찰청 형사기동대는 기아차 광주공장에 <b>취업</b>시켜주겠다며 돈을 받아 챙긴 혐의(사기)로 전 기아차 직원... ',
#   'link': 'http://www.jnilbo.com/76270823530',
#   'org_link': 'http://www.jnilbo.com/76270823530',
#   'pDate': '2025-02-27 16:36:00',
#   'title': '기아차 광주공장 <b>취업</b>사기 신고 잇달아…수사 확대'},
#  {'cnt': 66,
#   'description': '또 <b>취업</b> 후 학생들이 상환하는 학자금의 대출 금리 상한이 국채의 3년간 평균수익률 120%에서 110%로 낮아진다.... 교육부장관 및 교육감은 현장실습 환경의 안전성, <b>취업</b> 연계성, 직무 분야의 전공 적합성 등을 고려해 우수... ',
#   'link': 'http://news.mt.co.kr/mtview.php?no=2025022714142640839',
#   'org_link': 'http://news.mt.co.kr/mtview.php?no=2025022714142640839',
#   'pDate': '2025-02-27 16:36:00',
#   'title': '교육감, 교원 정신건강 관리하도록..9개 법안 국무회의 통과'},
#  {'cnt': 67,
#   'description': "청년층의 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 2022년부터 꾸준히 추진해 오고 있다. KB국민은행... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이날 발대식에는 과거 'KB IT's Your Life'를 수료한 KB국민은행 재직... ",
#   'link': 'https://www.newspim.com/news/view/20250227000818',
#   'org_link': 'https://www.newspim.com/news/view/20250227000818',
#   'pDate': '2025-02-27 16:36:00',
#   'title': "KB국민은행, KB IT's Your Life 6기 발대식 개최…청년 IT 인재 양성"},
#  {'cnt': 68,
#   'description': '이밖에 <b>취업</b>특강, AI 모의면접, 1:1 <b>취업</b>컨설팅 등 <b>취업</b>을 준비하는 학생들을 위한 실질적이고 다양한 프로그램을 진행했다. 특히 20개의 수소기업 홍보 부스에서는 직무 멘토링과 채용 상담을 통해 수소기업의 다양한... ',
#   'link': 'https://www.energy-news.co.kr/news/articleView.html?idxno=211118',
#   'org_link': 'https://www.energy-news.co.kr/news/articleView.html?idxno=211118',
#   'pDate': '2025-02-27 16:34:00',
#   'title': "수소기업과 우수인재의 '특별한 만남'…'기회의 장' 열려"},
#  {'cnt': 69,
#   'description': '데브코스 커리어 TALK는 주니어 개발자 및 IT 직군 <b>취업</b> 준비생을 위한 무료 특강으로, 프로그래머스가 주최하는 커리어 지원 프로그램이다. 올해 세 번째로 열리는 이번 행사에는 글로벌 기업에서 활동 중인 윤인도... ',
#   'link': 'https://www.dailysecu.com/news/articleView.html?idxno=164106',
#   'org_link': 'https://www.dailysecu.com/news/articleView.html?idxno=164106',
#   'pDate': '2025-02-27 16:34:00',
#   'title': "그렙, '프로그래머스 데브코스 커리어 TALK' 온·오프라인 동시 개최"},
#  {'cnt': 70,
#   'description': "청년층의 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 2022년부터 꾸준히 추진해 오고 있다. 특히... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이날 발대식에는 과거 'KB IT's Your Life'를 수료한 KB국민은행 재직 직원들의... ",
#   'link': 'https://www.delighti.co.kr/news/articleView.html?idxno=92643',
#   'org_link': 'https://www.delighti.co.kr/news/articleView.html?idxno=92643',
#   'pDate': '2025-02-27 16:34:00',
#   'title': "KB국민은행, 청년 IT 인재 양성 프로그램 'KB IT`s Your Life' 6기 발대식"},
#  {'cnt': 71,
#   'description': '데브코스는 프로그래머스가 주최하는 커리어 지원 특강으로, 주니어 개발자와 대한민국 IT 직군 <b>취업</b>을 희망하는 청년들을 위해 무료로 진행해오고 있다. 올해 3회차를 맞는 이번 행사에서는 글로벌 기업에 재직 중인... ',
#   'link': 'https://www.epnc.co.kr/news/articleView.html?idxno=313244',
#   'org_link': 'https://www.epnc.co.kr/news/articleView.html?idxno=313244',
#   'pDate': '2025-02-27 16:34:00',
#   'title': "그렙, '프로그래머스 데브코스 커리어 TALK' 개최"},
#  {'cnt': 72,
#   'description': "청년층의 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 2022년부터 꾸준히 추진해 오고 있다. 특히... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이날 발대식에는 과거 'KB IT's Your Life'를 수료한 KB국민은행 재직... ",
#   'link': 'http://www.whitepaper.co.kr/news/articleView.html?idxno=243649',
#   'org_link': 'http://www.whitepaper.co.kr/news/articleView.html?idxno=243649',
#   'pDate': '2025-02-27 16:34:00',
#   'title': "KB국민은행, 청년 IT 인재 양성 'KB IT's Your Life' 6기 발대식"},
#  {'cnt': 73,
#   'description': '공모대상 분야는 국민 복지, 일상·안전, <b>취업</b>·일자리, 산업·기업, 기타 등 5개 분야로 옥천군민과 관내 기업체·단체 누구나 참여할 수 있다. 군 홈페이지 공고란에 공지 되어있는 제안서 양식을 작성 후 우편 또는 이메일... ',
#   'link': 'http://www.newstnt.com/news/articleView.html?idxno=463113',
#   'org_link': 'http://www.newstnt.com/news/articleView.html?idxno=463113',
#   'pDate': '2025-02-27 16:32:00',
#   'title': '옥천군, 군민 대상 생활 속 규제개혁 아이디어 공모'},
#  {'cnt': 74,
#   'description': '이 사업은 <b>취업</b>과 창업을 준비하는 청년과 중소기업 근로자를 위한 맞춤형 주거 공간으로, <b>취업</b>지원 라운지와 공유 오피스 등 특화시설이 함께 조성될 예정이다. 2026년 착공, 2029년 준공을 목표로 추진된다. 원도심... ',
#   'link': 'https://www.newsfreezone.co.kr/news/articleView.html?idxno=611557',
#   'org_link': 'https://www.newsfreezone.co.kr/news/articleView.html?idxno=611557',
#   'pDate': '2025-02-27 16:32:00',
#   'title': '대전시, 청년·신혼부부 주거 혁신 가속'},
#  {'cnt': 75,
#   'description': '노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양, 간호, 호스피스 등을 위한 간호조무사를 양성하고 있다. 이... ',
#   'link': 'https://www.ibabynews.com/news/articleView.html?idxno=127195',
#   'org_link': 'https://www.ibabynews.com/news/articleView.html?idxno=127195',
#   'pDate': '2025-02-27 16:32:00',
#   'title': "'저출생·고령화 해결사'로 나선 부영그룹 이중근 회장, 저고위로부터 ..."},
#  {'cnt': 76,
#   'description': '그는 20년 전 한국 조리 대학교에서 공부한 뒤 해외에서 <b>취업</b>하면서 요리를 시작했다. 그는 “요리를 시작할 때 미쉐린 가이드 존재를 알았지만, 당시는 미쉐린 스타가 아니고 가이드에 선정된 레스토랑에 가서 밥만... ',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04624806642074784',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04624806642074784',
#   'pDate': '2025-02-27 16:31:00',
#   'title': "안성재 이어 '3스타' 채운 강민구 셰프 &quot;난 노력파&quot;"},
#  {'cnt': 77,
#   'description': '한국마사회는 지난해 8월, 청년들에게 양질의 일자리 제공과 <b>취업</b> 실무 역량을 배양하기 위해 35명을... 청년들의 <b>취업</b> 역량 개발과 실무적 이해도 향상에 도움이 될 수 있도록 노력하겠다&quot;고 밝혔다. 한국마사회는... ',
#   'link': 'https://www.gukjenews.com/news/articleView.html?idxno=3212667',
#   'org_link': 'https://www.gukjenews.com/news/articleView.html?idxno=3212667',
#   'pDate': '2025-02-27 16:30:00',
#   'title': '꿈을 향한 첫걸음! 한국마사회, 2024년 체험형 청년인턴 수료식 개최'},
#  {'cnt': 78,
#   'description': "<b>취업</b>제한명령 위반자 적발 체육시설 근무 20명 '최다' 아동학대 관련 범죄 전력이 있는 33명이 <b>취업</b>제한명령을 위반하고 아동 관련기관에서 일하다 적발됐다. 보건복지부는 관계부처와 함께 지난해 4월부터 12월까지... ",
#   'link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160287410468171',
#   'org_link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160287410468171',
#   'pDate': '2025-02-27 16:30:00',
#   'title': '아동학대 전과자 33명 아동기관서 근무'},
#  {'cnt': 79,
#   'description': "이 중 1535명은 시니어클럽을 통해 공익활동, 노인역량 활용, 공동체 사업단, <b>취업</b> 지원형 사업 등에 투입된다. 또 신규 일자리로 '주5일식사 제공 급식 도우미', '영농폐기물배출분리사업', '시니어홍보사업단', '문화재... ",
#   'link': 'http://www.koreareport.co.kr/news/articleView.html?idxno=32992',
#   'org_link': 'http://www.koreareport.co.kr/news/articleView.html?idxno=32992',
#   'pDate': '2025-02-27 16:30:00',
#   'title': '나주시, 2025년 노인일자리 사업 시작 …4025명 고용'},
#  {'cnt': 80,
#   'description': '건설업의 <b>취업</b> 한파가 제조업으로 옮겨붙은 모습도 확인됐다. 같은 기간 제조업은 1만1000명 감소했다. 제조업 종사자가 감소세를 보인 것은 2021년 5월(-8300명) 이후 43개월 만이다. 김재훈 고용부... ',
#   'link': 'https://www.joongang.co.kr/article/25317089',
#   'org_link': 'https://www.joongang.co.kr/article/25317089',
#   'pDate': '2025-02-27 16:29:00',
#   'title': '사업체 종사자, 4년 만에 첫 ‘마이너스’…&quot;건설업 침체 영향&quot;'},
#  {'cnt': 81,
#   'description': '양 의원은 &quot;2025년 2월 현재 제주 경제는 침체의 늪에서 벗어나지 못하고 있다&quot;며 &quot;관광객 감소, 소비 위축, 건설 부진, <b>취업</b>자 수 감소 등의 문제가 겹치며 단기적인 하방 위험이 커지고 있다&quot;고 진단햇다. 이어 &quot;관광업... ',
#   'link': 'http://www.headlinejeju.co.kr/news/articleView.html?idxno=564164',
#   'org_link': 'http://www.headlinejeju.co.kr/news/articleView.html?idxno=564164',
#   'pDate': '2025-02-27 16:28:00',
#   'title': "양영수 의원 &quot;경제위기극복 '전 도민 10만원' 민생지원금 제안&quot;"},
#  {'cnt': 82,
#   'description': '청년 <b>취업</b> 고용지원 등 현안 추진을 위한 당정협의회를 개최했다. 권 의원은 “오늘 당정 협의는 특례시 승격... 이어 권 의원은 ▲경계선지능 청년 <b>취업</b> 고용지원 ▲화성시 저탄소도시 적극 추진 ▲화성시 지역사회... ',
#   'link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=2012994',
#   'org_link': 'http://www.shinailbo.co.kr/news/articleView.html?idxno=2012994',
#   'pDate': '2025-02-27 16:28:00',
#   'title': '민주당 화성병 지역위, 화성특례시 승격 후 첫 당정 협의 개최'},
#  {'cnt': 83,
#   'description': '공사는 서포터즈 활동을 지원하기 위해 소정의 활동비를 지원하고 개개인의 역량강화 및 유대감 증진을 위해 인천공항 팸투어, 콘텐츠 제작 교육, 항공분야 진로·<b>취업</b> 멘토링, 선배 기수 초청 홈커밍데이 등 다양한... ',
#   'link': 'https://www.polinews.co.kr/news/articleView.html?idxno=683487',
#   'org_link': 'https://www.polinews.co.kr/news/articleView.html?idxno=683487',
#   'pDate': '2025-02-27 16:28:00',
#   'title': '인천공항공사, 제5기 SNS 서포터즈 발대식 개최'},
#  {'cnt': 84,
#   'description': '데브코스는 프로그래머스가 주최하는 커리어 지원 특강으로 주니어 개발자와 대한민국 IT 직군 <b>취업</b>을 희망하는 청년들을 위해 무료로 진행해오고 있다. 올해 3회차를 맞는 이번 행사에서는 글로벌 기업에 재직 중인... ',
#   'link': 'https://www.gosiweek.com/article/1065597952864033',
#   'org_link': 'https://www.gosiweek.com/article/1065597952864033',
#   'pDate': '2025-02-27 16:28:00',
#   'title': "그렙, “AI 시대 개발자 생존 전략! '프로그래머스 데브코스 커리어 TAL..."},
#  {'cnt': 85,
#   'description': '청년층 고용률 역시 44.8%에 그치며 청년 절반가량이 자의든 타의든 <b>취업</b>을 하지 못한 것으로 나타났다. 아무... 정부는 이 같은 문제를 해결하기 위해 민관 합동으로 미래의 주역인 청년들의 <b>취업</b>을 촉진하기 위한 다양한... ',
#   'link': 'https://www.joongdo.co.kr/web/view.php?key=20250227010008609',
#   'org_link': 'https://www.joongdo.co.kr/web/view.php?key=20250227010008609',
#   'pDate': '2025-02-27 16:28:00',
#   'title': "[기업] 해마다 느는 '쉬었음 청년', 대전지역 3대 고용지원정책으로 해..."},
#  {'cnt': 86,
#   'description': '△대외협력부총장(경영전략부총장 겸직) 이경수 △기획조정처장 이희용 △학생성공처장(진로<b>취업</b>실장 겸직) 이경탁 △인권센터장 조지은 △교무처 AI스마트교육센터장 최영욱 △국제처 글로벌입학본부장(국제부처장... ',
#   'link': 'https://www.kyongbuk.co.kr/news/articleView.html?idxno=4032898',
#   'org_link': 'https://www.kyongbuk.co.kr/news/articleView.html?idxno=4032898',
#   'pDate': '2025-02-27 16:28:00',
#   'title': '[인사] 영남대'},
#  {'cnt': 87,
#   'description': '또한 보호 관찰과 아동학대 재범 예방 강의 40시간 수강, 아동 관련 기관 <b>취업</b> 제한 3년도 명했다. A 씨는 2023년 5월부터 9월 사이 7차례에 걸쳐 모 병원 입원실에서 자신이 홀로 키우는 어린 두 아이들에게 성인용... ',
#   'link': 'https://www.donga.com/news/Society/article/all/20250227/131118684/2',
#   'org_link': 'https://www.donga.com/news/Society/article/all/20250227/131118684/2',
#   'pDate': '2025-02-27 16:28:00',
#   'title': '“애들 입원하니 편해”…강제로 감기약 먹여 퇴원 늦춘 엄마'},
#  {'cnt': 88,
#   'description': "부산진구가 청년들의 <b>취업</b> 역량을 강화하기 위해 차별화된 원스톱 <b>취업</b>지원 사업을 시행합니다. 부산진구는 당감동에 있는 청년공간인 '청년마루'를 일자리 카페로 새단장해 운영합니다. 이 곳에는 상시 상담이 가능한... ",
#   'link': 'http://news.lghellovision.net/news/articleView.html?idxno=498557',
#   'org_link': 'http://news.lghellovision.net/news/articleView.html?idxno=498557',
#   'pDate': '2025-02-27 16:28:00',
#   'title': '부산진구, 원스톱 청년<b>취업</b>지원사업 시행'},
#  {'cnt': 89,
#   'description': '기관 <b>취업</b> 제한 3년을 명했다. A씨는 2023년 5월부터 9월 사이 7차례에 걸쳐 모 병원 입원 병실 등지에서 어린 두 아들들에게 성인용 감기약을 일부러 먹이거나 수액에 섞어 투여토록 해 구토를 유발, 신체적 학대를 한... ',
#   'link': 'http://www.fnnews.com/news/202502271611206295',
#   'org_link': 'http://www.fnnews.com/news/202502271611206295',
#   'pDate': '2025-02-27 16:27:00',
#   'title': '“육아 힘들어서 퇴원 늦추려고” 두 아들에게 ‘성인용 감기약’ 먹인...'},
#  {'cnt': 90,
#   'description': '(진로<b>취업</b>실장 겸직) 이경탁 △국제처 글로벌입학본부장(국제부처장 겸직) 유수경 △학생성공부처장 김춘영 △기획조정부처장 김병수 △기획조정부처장 박재찬 ◆동아대 △소프트웨어대학장 이석환 △간호대학장 강지연... ',
#   'link': 'https://www.hankookilbo.com/News/Read/A2025022716020002904?did=NA',
#   'org_link': 'https://www.hankookilbo.com/News/Read/A2025022716020002904?did=NA',
#   'pDate': '2025-02-27 16:27:00',
#   'title': '[인사] 외교부 외'},
#  {'cnt': 91,
#   'description': '신청 대상은 은평구에 거주하는 경력보유여성 또는 <b>취업</b>희망여성으로 선발인원은 과정별 12명에서 20명이다.... 구는 <b>취업</b>시장의 수요를 반영한 전망 있는 다양한 프로그램을 개발해 여성의 사회·경제활동 복귀를... ',
#   'link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160292327658507',
#   'org_link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160292327658507',
#   'pDate': '2025-02-27 16:26:00',
#   'title': '은평구, 경력보유여성 대상 취·창업지원 프로그램 수강생모집'},
#  {'cnt': 92,
#   'description': '직군 <b>취업</b> 준비생을 위한 실무 노하우를 공유할 예정이다. 데브코스 커리어 TALK는 주니어 개발자 및 IT 직군 <b>취업</b>을 준비하는 청년들을 위해 마련된 무료 특강이다. 올해 세 번째로 열리는 이번 행사에는 글로벌... ',
#   'link': 'https://www.nbntv.co.kr/news/articleView.html?idxno=3034337',
#   'org_link': 'https://www.nbntv.co.kr/news/articleView.html?idxno=3034337',
#   'pDate': '2025-02-27 16:26:00',
#   'title': "그렙, '데브코스 커리어 TALK' 개최"},
#  {'cnt': 93,
#   'description': '&lt;사진&gt; 교통과와 범죄예방진단팀(CPO) 담당자가 합동으로 진행한 이번 교육은 약 30개국의 다양한 국적을 가진 유학생을 대상으로 △보이스피싱 △불법 <b>취업</b> △마약 △성범죄 △음주 운전 예방 교육 △외국인 운전면허... ',
#   'link': 'https://www.kbmaeil.com/news/articleView.html?idxno=1032928',
#   'org_link': 'https://www.kbmaeil.com/news/articleView.html?idxno=1032928',
#   'pDate': '2025-02-27 16:26:00',
#   'title': '포항북부경찰서, 한동대 외국인 유학생 대상 범죄예방·교통안전 교육 ...'},
#  {'cnt': 94,
#   'description': '또한 GS25 은평모아점 등 자활기업 6개소의 운영을 지원하고 <b>취업</b> 지원 등 체계적이고 전문적인 자활서비스를 제공하고 있다. 최민준 센터장은 “서울은평지역자활센터의 문화나눔 포인트사업이 자활근로 참여자분들에게... ',
#   'link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160292375197490',
#   'org_link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160292375197490',
#   'pDate': '2025-02-27 16:26:00',
#   'title': '은평구, 서울지역자활센터 자활참여자 대상 문화나눔포인트 지원사업 시...'},
#  {'cnt': 95,
#   'description': '모집대상은 △최근 6개월 이상 <b>취업</b> 및 직업훈련 이력이 없고, 구직 문답표 점수가 21점 이상인 18~34세 이하 청년 △자립준비청년 △청소년 복지시설 입·퇴소 청년 △북한이탈청년 등이다. 이 외에도 △<b>취업</b> 취약계층... ',
#   'link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160288337559280',
#   'org_link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160288337559280',
#   'pDate': '2025-02-27 16:26:00',
#   'title': '‘꿈을 위한 재도약’ 인천시 남동구, 청년 도전 지원사업 참여자 모집'},
#  {'cnt': 96,
#   'description': '모집 대상은 공고일 기준 은평구에 거주하는 19세 이상 39세 이하 미<b>취업</b> 청년이다. 지원하고자 하는 청년은... 제공하고자 한다”며 “이번 기회를 통해 직무 경력을 획득하고 <b>취업</b>경쟁력을 강화하길 바란다”고 말했다.',
#   'link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160292222264109',
#   'org_link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160292222264109',
#   'pDate': '2025-02-27 16:26:00',
#   'title': '“함께 성장하는 청년의 내일”··· 은평구, 청년 일자리사업 참여 청...'},
#  {'cnt': 97,
#   'description': '금융사 <b>취업</b> 준비생의 자산 형성을 위한 금융 노하우를 전했다. 또 20여년 다양한 금융사 재직 경험을 바탕으로 금융업종별 특징교육에서 좋은 평가를 받았다. 특히 예비 금융인을 준비하는 <b>취업</b> 준비생들을 대상으로... ',
#   'link': 'https://biz.newdaily.co.kr/site/data/html/2025/02/27/2025022700306.html',
#   'org_link': 'https://biz.newdaily.co.kr/site/data/html/2025/02/27/2025022700306.html',
#   'pDate': '2025-02-27 16:24:00',
#   'title': 'JT저축은행, 1사1교 금융교육 우수사례 선정 …금감원장 표창 수상'},
#  {'cnt': 98,
#   'description': "'청년도전 지원사업'은 <b>취업</b>에 어려움을 느끼고 구직활동을 하지 않는 청년들에게 맞춤형 프로그램을... 사업 지원 대상은 △최근 6개월 이상 <b>취업</b> 또는 교육, 직업훈련 이력이 없는 청년 △자립 준비 청년 △청소년... ",
#   'link': 'https://news.tf.co.kr/read/national/2183370.htm',
#   'org_link': 'https://news.tf.co.kr/read/national/2183370.htm',
#   'pDate': '2025-02-27 16:24:00',
#   'title': "시흥시-노동부 안산지청, '청년도전 지원사업' 지원약정 체결"},
#  {'cnt': 99,
#   'description': "청년층의 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 2022년부터 꾸준히 추진해 오고 있다. 특히, 고용노동부가... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이날 발대식에는 과거 'KB IT's Your Life'를 수료한 KB국민은행 재직... ",
#   'link': 'http://www.sisaon.co.kr/news/articleView.html?idxno=168647',
#   'org_link': 'http://www.sisaon.co.kr/news/articleView.html?idxno=168647',
#   'pDate': '2025-02-27 16:24:00',
#   'title': "함영주 하나금융 회장, 밸류업 청사진 제시…&quot;금융지주 저평가, 'PBR 1배..."},
#  {'cnt': 100,
#   'description': '이 중 1535명은 시니어클럽을 통해 공익활동, 노인역량 활용, 공동체 사업단, <b>취업</b> 지원형 사업 등에 투입된다. 또 신규 일자리로 ‘주5일식사 제공 급식 도우미’, ‘영농폐기물 배출분리사업’... ',
#   'link': 'https://www.nspna.com/news/?mode=view&newsid=742309',
#   'org_link': 'https://www.nspna.com/news/?mode=view&newsid=742309',
#   'pDate': '2025-02-27 16:24:00',
#   'title': '나주시, 민선8기 최대 4025명 고용 노인일자리 사업 시작'},
#  {'cnt': 101,
#   'description': '금융사 <b>취업</b> 준비생의 자산 형성을 위한 금융 노하우를 전했다. 또 20여년 다양한 금융사 재직 경험을 바탕으로 금융업종별 특징교육에서 좋은 평가를 받았다. 특히 예비 금융인을 준비하는 <b>취업</b> 준비생들을 대상으로... ',
#   'link': 'https://biz.newdaily.co.kr/site/data/html/2025/02/27/2025022700306.html',
#   'org_link': 'https://biz.newdaily.co.kr/site/data/html/2025/02/27/2025022700306.html',
#   'pDate': '2025-02-27 16:24:00',
#   'title': 'JT저축은행, 1사1교 금융교육 우수사례 선정 …금감원장 표창 수상'},
#  {'cnt': 102,
#   'description': "'청년도전 지원사업'은 <b>취업</b>에 어려움을 느끼고 구직활동을 하지 않는 청년들에게 맞춤형 프로그램을... 사업 지원 대상은 △최근 6개월 이상 <b>취업</b> 또는 교육, 직업훈련 이력이 없는 청년 △자립 준비 청년 △청소년... ",
#   'link': 'https://news.tf.co.kr/read/national/2183370.htm',
#   'org_link': 'https://news.tf.co.kr/read/national/2183370.htm',
#   'pDate': '2025-02-27 16:24:00',
#   'title': "시흥시-노동부 안산지청, '청년도전 지원사업' 지원약정 체결"},
#  {'cnt': 103,
#   'description': '고용률은 <b>취업</b>자 수를 15세 이상 인구수로 나눈 것이다. 수원시는 경제위기를 극복하고, 민생경제를 회복하기 위해 올해 ‘지역 일자리 3만 6000개 창출’을 목표로 설정하고 노인·장애인·청년 등 <b>취업</b>... ',
#   'link': 'https://www.seoul.co.kr/news/publicnews/local_govern/2025/02/27/20250227500191?wlog_tag3=naver',
#   'org_link': 'https://www.seoul.co.kr/news/publicnews/local_govern/2025/02/27/20250227500191?wlog_tag3=naver',
#   'pDate': '2025-02-27 16:23:00',
#   'title': '수원시 지난해 하반기 고용률 62.9%, 역대 최고 찍었다'},
#  {'cnt': 104,
#   'description': '청년층의 IT 역량 향상과 <b>취업</b>경쟁력 제고를 위해 2022년부터 추진하고 있는 KB국민은행의 대표... 분야에 <b>취업</b>해 IT인재로 성장하고 있다. 이번 6기 참가자들은 6개월간 JAVA 기반 알고리즘, SQL, DB 활용 및 팀... ',
#   'link': 'https://www.raonnews.com/news/article.html?no=45009',
#   'org_link': 'https://www.raonnews.com/news/article.html?no=45009',
#   'pDate': '2025-02-27 16:22:00',
#   'title': 'KB국민은행, 청년 IT 인재 양성 프로그램 6기 발대식 개최'},
#  {'cnt': 105,
#   'description': '데브코스 커리어 TALK는 주니어 개발자 및 IT 직군 <b>취업</b>을 준비하는 청년들을 위한 무료 특강이다. 이번 행사는 글로벌 기업에서 활동 중인 윤인도 엔지니어와 프로그래머스 이선희 데브코스 교육개발지원팀장이 연사로... ',
#   'link': 'https://www.gokorea.kr/news/articleView.html?idxno=820960',
#   'org_link': 'https://www.gokorea.kr/news/articleView.html?idxno=820960',
#   'pDate': '2025-02-27 16:22:00',
#   'title': "그렙, '데브코스 커리어 TALK' 온·오프라인 동시 개최"},
#  {'cnt': 106,
#   'description': '평택시 지역상생 협력대학 도약 : 평택시-지역대학 협력사업 특화사업 수행, 평택시 계약학과 등록금 지원, <b>취업</b> 장학 지원 등 9. 봄맞이 개방 벚꽃거리 개최, 8만여명 방문 : 지역대표 벚꽃명소인 평택대학교 캠퍼스... ',
#   'link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160286686114155',
#   'org_link': 'https://www.siminilbo.co.kr/news/newsview.php?ncode=1160286686114155',
#   'pDate': '2025-02-27 16:22:00',
#   'title': '평택대, 2024년 10대뉴스'},
#  {'cnt': 107,
#   'description': '지난 1998년부터 지난해까지 총 7012명에게 약 124억 원의 장학금을 지급했으며, 사회적 자립을 위한 <b>취업</b>지원 프로그램 ‘스탠드업’과 견문 확대 기회를 제공하는 ‘비전캠프’ 프로그램 등을 운영하고 있다.... ',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202502271141095977a9fc143920_1/article.html',
#   'org_link': 'http://www.g-enews.com/ko-kr/news/article/news_all/202502271141095977a9fc143920_1/article.html',
#   'pDate': '2025-02-27 16:22:00',
#   'title': "도로공사, 3월 4일까지 고속도로 사고 피해자 심리치료 위한 '안아드림..."},
#  {'cnt': 108,
#   'description': '경기도에서 한식당을 운영하는 외식업주의 자녀 최 모 양은 &quot;우아한 사장님 자녀 장학금 덕분에 무리한 아르바이트 없이 <b>취업</b> 준비에 전념할 수 있었고 원하는 결과를 이룰 수 있었다&quot;며 소감을 전했다. 기존에는... ',
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=676607',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=676607',
#   'pDate': '2025-02-27 16:22:00',
#   'title': '배민, 외식업주 자녀에 장학금 지원…연간 최대 400만원'},
#  {'cnt': 109,
#   'description': '키우고 <b>취업</b> 경쟁력을 높이기 위해 추진해왔다. 이 프로그램은 고용노동부의 디지털 핵심 실무인재... 또한, KB국민은행은 교육생들에게 자기주도학습비 지원, 1대1 <b>취업</b> 컨설팅, 현직자와 함께하는 금융... ',
#   'link': 'https://www.koreaittimes.com/news/articleView.html?idxno=138848',
#   'org_link': 'https://www.koreaittimes.com/news/articleView.html?idxno=138848',
#   'pDate': '2025-02-27 16:20:00',
#   'title': "KB국민은행, 청년 IT 인재 양성 프로그램 'KB IT's Your Life' 6기 발대식..."},
#  {'cnt': 110,
#   'description': '젊은 시절 화염병을 던지고, 공장에 위장 <b>취업</b>을 하고, 또 삐라를 뿌리던 태수 씨는 노동문제에 관심이 많으나 정작 자신의 집 안에서 이루어지는 가사 노동에 대해서는 일언반구도 하지 않는 인물이다. 그의 딸 수민은... ',
#   'link': 'http://www.jjn.co.kr/news/articleView.html?idxno=998342',
#   'org_link': 'http://www.jjn.co.kr/news/articleView.html?idxno=998342',
#   'pDate': '2025-02-27 16:20:00',
#   'title': '이상의 문학적 정신-성취-업적 기려'},
#  {'cnt': 111,
#   'description': '학생들의 <b>취업</b> 경쟁력을 높이기 위해 다양한 <b>취업</b> 지원 프로그램을 운영하고 있다. <b>취업</b>가이드북 제작, <b>취업</b> 멘토링, 실전 면접 클리닉 등 맞춤형 <b>취업</b> 지원책을 제공하며, 졸업생 네트워크를 활용한 병원 별 맞춤 <b>취업</b>... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2243335',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2243335',
#   'pDate': '2025-02-27 16:20:00',
#   'title': '경복대학교 간호학과, &quot;시대가 요구하는 전문 간호인력 양성&quot;'},
#  {'cnt': 112,
#   'description': '이 회장은 노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은 현재 라오스와 캄보디아 등 동남아시아에 간호대학을 설립해 노인요양, 간호, 호스피스 등을 위한 간호조무사를 양성하고... ',
#   'link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04592006642074784',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=04592006642074784',
#   'pDate': '2025-02-27 16:19:00',
#   'title': '‘직원 출산하면 1억’ 통 큰 부영 회장님, 결국'},
#  {'cnt': 113,
#   'description': '또 보호 관찰과 아동학대 재범 예방 강의 40시간 수강, 아동 관련 기관 <b>취업</b> 제한 3년을 명했다. A씨는 2023년 5월부터 9월 사이 7차례에 걸쳐 모 병원 입원 병실 등지에서 자신이 홀로 키우는 1세·3세 두 아들에게 성인용... ',
#   'link': 'https://www.seoul.co.kr/news/society/accident/2025/02/27/20250227500187?wlog_tag3=naver',
#   'org_link': 'https://www.seoul.co.kr/news/society/accident/2025/02/27/20250227500187?wlog_tag3=naver',
#   'pDate': '2025-02-27 16:18:00',
#   'title': '“입원시키니 편해”…1세·3세 아들에 성인 감기약 먹인 엄마'},
#  {'cnt': 114,
#   'description': '주로 다른 업종에 견줘 임금이나 근로 조건이 열악한 건설 현장에 청년층이 <b>취업</b>하고 기존 건설 노동자의 숙련을 반영하도록 제도를 개편하는 내용이다. 노동부는 2021년에 도입됐으나 유명무실하게 운용되는... ',
#   'link': 'https://www.hani.co.kr/arti/society/labor/1184561.html',
#   'org_link': 'https://www.hani.co.kr/arti/society/labor/1184561.html',
#   'pDate': '2025-02-27 16:18:00',
#   'title': '정부, 건설업 적정임금제 보장 방안 발표…노조 “업체 지원책”'},
#  {'cnt': 115,
#   'description': '광운대학교는 지난 17일부터 18일까지 이틀간 광운대학교에서 벤처스타트업 아카데미 SW <b>취업</b> 캠프가 진행됐다고 27일 밝혔다. 광운대 벤처스타트업아카데미 사업단이 주최한 SW <b>취업</b>캠프에서는 예비 졸업생들이 IT 기업... ',
#   'link': 'http://www.popcornnews.net/news/articleView.html?idxno=73828',
#   'org_link': 'http://www.popcornnews.net/news/articleView.html?idxno=73828',
#   'pDate': '2025-02-27 16:18:00',
#   'title': '광운대학교 벤처스타트업아카데미 SW <b>취업</b> 캠프 개최...실질적 <b>취업</b> 준...'},
#  {'cnt': 116,
#   'description': '운영은 단기(5주 이상)와 중기(15주 이상), 장기(25주 이상) 등으로 나눠 자신감 회복이나 진로탐색 <b>취업</b>역량 강화 지역기업 연계 취 창업 교육 등 맞춤형 프로그램으로 운영한다. 프로그램 이수자에게는 단기 50만원... ',
#   'link': 'https://www.kukinews.com/article/view/kuk202502270187',
#   'org_link': 'https://www.kukinews.com/article/view/kuk202502270187',
#   'pDate': '2025-02-27 16:18:00',
#   'title': "김해추모공원 일원에 '김해 공설 자연장지' 조성"},
#  {'cnt': 117,
#   'description': '노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양, 간호, 호스피스 등을 위한 간호조무사를 양성하고 있다. 이... ',
#   'link': 'http://www.dizzotv.com/site/data/html_dir/2025/02/27/2025022780188.html',
#   'org_link': 'http://www.dizzotv.com/site/data/html_dir/2025/02/27/2025022780188.html',
#   'pDate': '2025-02-27 16:18:00',
#   'title': "'저출산 극복 마중물'…부영그룹 이중근 회장, 저고위로부터 감사패 받..."},
#  {'cnt': 118,
#   'description': '잡플래닛 관계자는 “이번 어워즈를 통해 <b>취업</b>·이직을 고민하는 구직자들에게 신뢰할 수 있는 커리어 가이드를 제공하고자 한다”며 “앞으로도 객관적인 데이터와 심층 평가를 바탕으로 우수 기업을 지속적으로... ',
#   'link': 'https://www.etnews.com/20250227000387',
#   'org_link': 'https://www.etnews.com/20250227000387',
#   'pDate': '2025-02-27 16:17:00',
#   'title': '잡플래닛, 일하기 좋은 기업 선정…네이버클라우드·구글코리아 뽑혀'},
#  {'cnt': 119,
#   'description': '이 회장은 재가 임종제도를 위해 재가 간병인 및 도우미 예산을 지원하자는 화두를 던졌으며 노인 돌봄을 위한 외국인 간호조무사들의 국내 <b>취업</b> 허용 등도 제안했다. 현존하는 인구관리 뿐만 아니라 정부의... ',
#   'link': 'https://www.psnews.co.kr/news/articleView.html?idxno=2083916',
#   'org_link': 'https://www.psnews.co.kr/news/articleView.html?idxno=2083916',
#   'pDate': '2025-02-27 16:17:00',
#   'title': '이중근 부영그룹 회장, 감사패 받아…저출생 추세 반전 기여 공로'},
# ...
#   'link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385047',
#   'org_link': 'https://www.businesspost.co.kr/BP?command=article_view&num=385047',
#   'pDate': '2025-02-27 08:42:00',
#   'title': '[인사] 뉴스핌, 영남대, 은행연합회'},
#  {'cnt': 962,
#   'description': "신한은행은 2021년부터 대표 사회공헌 사업인 '동행프로젝트'를 통해 사회안전망 사각지대에 놓인 저소득층, 장애인, 다문화가정 등 도움이 필요한 이웃들을 대상으로 기본적 생계지원과 더불어 디지털 교육, <b>취업</b>역량... ",
#   'link': 'https://www.newscj.com/news/articleView.html?idxno=3239166',
#   'org_link': 'https://www.newscj.com/news/articleView.html?idxno=3239166',
#   'pDate': '2025-02-27 08:40:00',
#   'title': '[기업 경영 특집] 신한은행, 고객·사회·환경과의 상생 가치 창출'},
#  {'cnt': 963,
#   'description': '보고서에 따르면, 특구사업이 약 8,889억 원의 생산 유발 효과와 6,952명의 <b>취업</b> 유발 효과를 창출했다고 분석했으나, 이에 대한 구체적인 검증이 이뤄지지 않았다는 지적이다. 손 의원은 CBD 원료의약품의 수출 실적이... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242817',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242817',
#   'pDate': '2025-02-27 08:40:00',
#   'title': '안동시의회 손광영 의원, 제255회 임시회 시정질문'},
#  {'cnt': 964,
#   'description': '경기도에서 한식당을 운영하는 외식업주의 자녀 최 모 양은 &quot;우아한 사장님 자녀 장학금 덕분에 무리한 아르바이트 없이 <b>취업</b> 준비에 전념할 수 있었고 원하는 결과를 이룰 수 있었다&quot;며 소감을 전했다. 기존에는... ',
#   'link': 'https://www.foodneconomy.com/news/articleView.html?idxno=410763',
#   'org_link': 'https://www.foodneconomy.com/news/articleView.html?idxno=410763',
#   'pDate': '2025-02-27 08:36:00',
#   'title': '배민, 외식업 사장님 자녀 지원 강화… 학업 장학금·멘토링·해외 탐방...'},
#  {'cnt': 965,
#   'description': '경남 김해 지역의 청년 고용률 향상에 이바지하는 한편, 젊은 세대의 <b>취업</b> 안정과 경제 활동에 기여할 것으로 예상된다. 지역 소상공인 제품 매입 확대를 통한 지역 경제 활성화 효과도 기대된다. 쿠팡은 지역 소상공인... ',
#   'link': 'https://www.foodneconomy.com/news/articleView.html?idxno=410761',
#   'org_link': 'https://www.foodneconomy.com/news/articleView.html?idxno=410761',
#   'pDate': '2025-02-27 08:34:00',
#   'title': '쿠팡, 김해에 AI 스마트물류센터 설립… 1450명 신규 고용 창출'},
#  {'cnt': 966,
#   'description': '및 <b>취업</b>지원 프로그램도 지원할 예정이다. 또한 자립준비청년들이 경제적 자립을 이룰 수 있도록 체계적... 적성에 맞는 진로설계를 위한 전문가의 1:1 진로코칭 프로그램부터 자격증 취득, <b>취업</b> 컨설팅, 인턴십 연계 등... ',
#   'link': 'https://www.newscj.com/news/articleView.html?idxno=3239165',
#   'org_link': 'https://www.newscj.com/news/articleView.html?idxno=3239165',
#   'pDate': '2025-02-27 08:34:00',
#   'title': '[기업 경영 특집] KB국민은행, 자립준비청년 경제력·정서적 역량강화 ...'},
#  {'cnt': 967,
#   'description': '한수원은 초록우산 어린이재단과 협업을 통해 자립준비청년들이 성공적으로 사회에 정착할 수 있도록 기초학습, 인턴십, 자립수당, <b>취업</b>축하금 및 <b>취업</b>지원비 등 자립 단계에 맞는 맞춤형 프로그램을 지원하고 있다. 이... ',
#   'link': 'http://www.energydaily.co.kr/news/articleView.html?idxno=153716',
#   'org_link': 'http://www.energydaily.co.kr/news/articleView.html?idxno=153716',
#   'pDate': '2025-02-27 08:34:00',
#   'title': "한수원, '열여덟 혼자서기' 인턴십 기관 현판 전달"},
#  {'cnt': 968,
#   'description': '사진|삼척시청 삼척시는 지역산업 특성에 적합한 일자리사업을 발굴하고 지역내 <b>취업</b>기회를 확대하고자 강원특별자치도에서 공모한 ‘2025년 지역산업맞춤형 일자리창출 지원 사업’에 선정되었다고 밝혔다. 선정된... ',
#   'link': 'https://www.sportsseoul.com/news/read/1497581?ref=naver',
#   'org_link': 'https://www.sportsseoul.com/news/read/1497581?ref=naver',
#   'pDate': '2025-02-27 08:33:00',
#   'title': '삼척시, 강원자치도 지역산업맞춤형 일자리창출 지원사업 공모 선정'},
#  {'cnt': 969,
#   'description': '한편 센터는 특수학급에 재학 중인 고등학생 및 특수학교 전공과 학생을 대상으로 직업상담과 직업평가, 개별화직업재활계획 수립을 시행해 맞춤형 진로‧직업교육, 사업체 현장훈련, <b>취업</b> 알선 등 직업재활... ',
#   'link': 'https://www.ablenews.co.kr/news/articleView.html?idxno=219060',
#   'org_link': 'https://www.ablenews.co.kr/news/articleView.html?idxno=219060',
#   'pDate': '2025-02-27 08:30:00',
#   'title': '제주장애청소년직업지도센터, 프로그램 참여 장애청소년 모집'},
#  {'cnt': 970,
#   'description': "실질적인 <b>취업</b> 정보를 제공하는 '찾아가는 센터 홍보' 행사를 성공적으로 마쳤다. 찾아가는 센터 홍보 행사 현장 /사진=경복대 제공 이번 행사는 졸업생들에게 대학일자리플러스센터에서 제공하는 다양한 <b>취업</b>지원... ",
#   'link': 'http://www.veritas-a.com/news/articleView.html?idxno=543918',
#   'org_link': 'http://www.veritas-a.com/news/articleView.html?idxno=543918',
#   'pDate': '2025-02-27 08:28:00',
#   'title': "경복대 대학일자리플러스센터, 졸업생과 함께한 '찾아가는 센터 홍보' ..."},
#  {'cnt': 971,
#   'description': '금융사의 경우 임원이 문책 경고를 받으면 동종업계로 <b>취업</b>이 불가능하지만, 두나무는 금융사에 해당하지... 문책 경고는 중징계로 해당 조치를 받은 임원은 금융사로 3년 동안 <b>취업</b>할 수 없다. 기존 회사에서 연임도... ',
#   'link': 'https://www.news1.kr/finance/blockchain-fintech/5702636',
#   'org_link': 'https://www.news1.kr/finance/blockchain-fintech/5702636',
#   'pDate': '2025-02-27 08:27:00',
#   'title': "두나무, 거래소 업계 CEO 최초 '중징계'…어떤 제재 받나"},
#  {'cnt': 972,
#   'description': '이들은 발달장애인의 디지털 교육 확대와 <b>취업</b> 기회 강화를 위해 김 후보의 당선을 염원한다고 밝혔다.... 이 외에도 △맞춤형 디지털 교육 프로그램 확대 △4차 산업혁명에 맞는 <b>취업</b>훈련 및 직업교육 강화 △포용적... ',
#   'link': 'https://www.getnews.co.kr/news/articleView.html?idxno=808978',
#   'org_link': 'https://www.getnews.co.kr/news/articleView.html?idxno=808978',
#   'pDate': '2025-02-27 08:20:00',
#   'title': '발달장애인 가족, 김석준 예비후보 지지 선언'},
#  {'cnt': 973,
#   'description': '주요 <b>취업</b>처로는 빅데이터 분석 기업, 인공지능 기술을 응용한 제품 개발 회사, 기업의 데이터 관리 부서... 또한 학생들은 해외 어학연수 및 <b>취업</b> 교육과정에 참여해 글로벌 경쟁력을 강화할 수 있다.... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242935',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242935',
#   'pDate': '2025-02-27 08:20:00',
#   'title': '경복대학교 빅데이터학과, 데이터 분석 및 AI 기술 활용할 인재 양성'},
#  {'cnt': 974,
#   'description': '이 사업은 <b>취업</b>과 창업을 준비하는 청년과 중소기업 근로자를 위한 맞춤형 주거 공간으로, <b>취업</b>지원 라운지와 공유 오피스 등 특화시설이 함께 조성될 예정이다. 2026년 착공, 2029년 준공을 목표로 추진된다. 원도심... ',
#   'link': 'https://daily.hankooki.com/news/articleView.html?idxno=1184454',
#   'org_link': 'https://daily.hankooki.com/news/articleView.html?idxno=1184454',
#   'pDate': '2025-02-27 08:20:00',
#   'title': '대전시, 청년·신혼부부 주거 혁신 가속'},
#  {'cnt': 975,
#   'description': '올해 상반기 대기업 채용시장이 지난해보다 어두울 것이라는 전망이 나왔다. 한국경제인협회(한경협)는 지난 4∼13일 리서치앤리서치에 의뢰해 매출액 500대 기업을 대상으로 조사한 결과, 응답 기업 61.1％는 올해... ',
#   'link': 'https://www.getnews.co.kr/news/articleView.html?idxno=808997',
#   'org_link': 'https://www.getnews.co.kr/news/articleView.html?idxno=808997',
#   'pDate': '2025-02-27 08:18:00',
#   'title': "<b>취업</b>전선 '한파주의보'... 대기업 61％ &quot;상반기 신규채용 없거나 미정&quot;"},
#  {'cnt': 976,
#   'description': '이번 프로그램은 오라클이 직접 설계·운영하는 교육 과정으로 글로벌 데이터베이스·클라우드·AI 분야의 최신 기술을 반영했으며, 오라클 고객사에서 총 64명의 채용을 약정, 관련 기업과 지속적인 협력을 통해 <b>취업</b>... ',
#   'link': 'https://www.sentv.co.kr/article/view/sentv202502270001',
#   'org_link': 'https://www.sentv.co.kr/article/view/sentv202502270001',
#   'pDate': '2025-02-27 08:16:00',
#   'title': '하이테커, ‘바이오헬스 데이터 분석가’ 1기 출범'},
#  {'cnt': 977,
#   'description': '및 <b>취업</b>·창업 지원 등 다양한 분야에서 상생 발전을 도모할 계획이다. 이병운 총장은 &quot;이번 협약은 우수 인재를 키워내고, 이를 지역과 산업으로 연계해 지속적인 동반성장을 이루기 위한 중요한 시작점&quot;이라며... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242861',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242861',
#   'pDate': '2025-02-27 08:15:00',
#   'title': "국립순천대-(주)로커스 애니메이션, '문화콘텐츠 특화분야' 업무협약"},
#  {'cnt': 978,
#   'description': '<b>취업</b>과 창업을 준비하는 청년과 중소기업 근로자를 위해 맞춤형 주거 공간을 제공하며, <b>취업</b>지원 라운지와 공유 오피스 등 특화 시설이 함께 마련될 예정이다. 청년들의 자립 기반을 강화하는 것은 물론, 지역 내 청년... ',
#   'link': 'https://www.ccdailynews.com/news/articleView.html?idxno=2327466',
#   'org_link': 'https://www.ccdailynews.com/news/articleView.html?idxno=2327466',
#   'pDate': '2025-02-27 08:14:00',
#   'title': '대전시, 청년·신혼부부 주거 혁신…2030년까지 2만호 공급'},
#  {'cnt': 979,
#   'description': '한수원은 초록우산 어린이재단과 협업을 통해 자립준비청년들이 성공적으로 사회에 정착할 수 있도록 기초학습, 인턴십, 자립수당, <b>취업</b>축하금 및 <b>취업</b>지원비 등 자립 단계에 맞는 맞춤형 프로그램을 지원하고 있다. 이... ',
#   'link': 'https://www.dailian.co.kr/news/view/1466622/?sc=Naver',
#   'org_link': 'https://www.dailian.co.kr/news/view/1466622/?sc=Naver',
#   'pDate': '2025-02-27 08:13:00',
#   'title': "한수원, 자립준비청년 '열여덟 혼자서기' 인턴십 기관 현판 전달"},
#  {'cnt': 980,
#   'description': '1부 행사의 사회는 이상원 학생<b>취업</b>처장이 맡았으며, 권형진 박문관장의 건국대 역사와 교시에 대한 특강으로 행사가 시작됐다. 뒤이어 오프닝 공연인 대북 퍼포먼스, 신입생 선서, 학생 윤리 선언, 장학증서 수여 등이... ',
#   'link': 'http://www.wsobi.com/news/articleView.html?idxno=270001',
#   'org_link': 'http://www.wsobi.com/news/articleView.html?idxno=270001',
#   'pDate': '2025-02-27 08:12:00',
#   'title': "건국대 '2025학년도 신입생 입학식' 개최"},
#  {'cnt': 981,
#   'description': '2022년 대학정보공시 기준 100% <b>취업</b>률을 기록한 소프트웨어융합과는 코딩, 사이버 보안, 클라우드 서비스... 컨설턴트로 <b>취업</b>할 수 있도록 한다. 클라우드 서비스 전공에서는 구글(Google), 아마존(Amazon)... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242923',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242923',
#   'pDate': '2025-02-27 08:10:00',
#   'title': '경복대학교 소프트웨어융합과, 4차 산업혁명 시대 주도할 인재 양성'},
#  {'cnt': 982,
#   'description': '<b>취업</b>·결혼 등으로 독립해 처음 자동차보험에 가입하게 되는 사회초년생 자녀의 보험료 부담을 완화하기 위해, 부모의 보험으로 운전한 청년층(19세~34세 이하) 자녀의 무사고 경력을 신규로 인정하고, 배우자도... ',
#   'link': 'https://mdtoday.co.kr/news/view/1065601466518070',
#   'org_link': 'https://mdtoday.co.kr/news/view/1065601466518070',
#   'pDate': '2025-02-27 08:10:00',
#   'title': '‘나이롱 환자’ 없앤다…교통사고 경상자에 ‘향후치료비’ 지급 금지'},
#  {'cnt': 983,
#   'description': '인스타그램에서 팔로워 증가든, 협찬 제안이든 의미 있는 변화가 없다면 다시 <b>취업</b>을 하기로 결심했어요. 그렇다고 단순히 콘텐츠만 많이 올린다고 되는 게 아니니까, 전략적으로 접근했어요. 인스타그램 콘텐츠를... ',
#   'link': 'https://www.travie.com/news/articleView.html?idxno=53858',
#   'org_link': 'https://www.travie.com/news/articleView.html?idxno=53858',
#   'pDate': '2025-02-27 08:10:00',
#   'title': '여행 콘텐츠로 2달 만에 10만 팔로워, 올리버여행기 인터뷰'},
#  {'cnt': 984,
#   'description': '전남 무안군은 <b>취업</b> 취약계층인 장애인의 사회참여 확대와 소득 증대를 위해 2025년 장애인일자리사업... 김산 무안군수는 &quot;<b>취업</b>을 희망하는 장애인들을 위해 지속적인 신규 일자리 발굴과 지원을 통해 장애인의 <b>취업</b>... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2243045',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2243045',
#   'pDate': '2025-02-27 08:05:00',
#   'title': '무안군, 장애인 경제적 자립 지원 추진'},
#  {'cnt': 985,
#   'description': '그간 시는 지역특화산업 집중육성과 우량기업 투자유치를 통한 일자리 창출뿐만 아니라, <b>취업</b> 취약계층 대상 공공일자리 확대에도 힘써 왔다. 지난해 ▲전북 최대 규모 미래 모빌리티 산업 기회발전특구 지정 ▲지역... ',
#   'link': 'http://www.hansbiz.co.kr/news/articleView.html?idxno=736249',
#   'org_link': 'http://www.hansbiz.co.kr/news/articleView.html?idxno=736249',
#   'pDate': '2025-02-27 08:04:00',
#   'title': '김제시, 역대 최고 68.8% 고용률 달성...전국 시 단위 3위'},
#  {'cnt': 986,
#   'description': '연수생들이 <b>취업</b>도 못 하고, 강제 출국당할 처지에 놓였습니다. 연수생들은 돈을 받은 한 직업학교를 사기 혐의로 고소했는데요. 어떤 이유인지, 문그린 기자가 취재했습니다. [리포트] <b>취업</b>을 꿈꾸고 2년 전 우리나라를... ',
#   'link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8186995&ref=A',
#   'org_link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8186995&ref=A',
#   'pDate': '2025-02-27 08:03:00',
#   'title': '<b>취업</b> 사기에 짓밟힌 ‘코리안 드림’'},
#  {'cnt': 987,
#   'description': '서울시장애인일자리통합지원센터(센터장 황보익)는 지난 26일 서울특별시 거주 중증장애인을 대상으로 <b>취업</b>스킬업강좌 1회차 프로그램을 실시했다. 이번 1회차 강의는 <b>취업</b> 준비 단계에 해당하는 사회초년생... ',
#   'link': 'https://www.ablenews.co.kr/news/articleView.html?idxno=219048',
#   'org_link': 'https://www.ablenews.co.kr/news/articleView.html?idxno=219048',
#   'pDate': '2025-02-27 08:02:00',
#   'title': "서울시장애인일자리통합지원센터, '<b>취업</b>스킬업강좌 1회차 프로그램' 실..."},
#  {'cnt': 988,
#   'description': "한국 <b>취업</b> 꿈꾼 베트남 청년들 울린 직업학교 ▲ 경남매일 = 김해 쿠팡 스마트물류센터 조성 ▲ 경남신문 = 도내 출생아 수 10년 만에 증가 ▲ 경남일보 = &quot;논란 접고 이젠 도약 준비할 때&quot; ▲ 경북매일 = '주가 껑충' 대구百... ",
#   'link': 'https://www.yna.co.kr/view/AKR20250227016300505?input=1195m',
#   'org_link': 'https://www.yna.co.kr/view/AKR20250227016300505?input=1195m',
#   'pDate': '2025-02-27 08:00:00',
#   'title': '[전국 주요 신문 톱뉴스](27일 조간)'},
#  {'cnt': 989,
#   'description': '이번 행사는 졸업생들에게 대학일자리플러스센터에서 제공하는 다양한 <b>취업</b>지원 프로그램을 소개하고, 보다 효과적인 <b>취업</b> 준비를 돕기 위해 기획됐다. 행사에서는 △대학일자리플러스센터 SNS 채널 가입 이벤트... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242915',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2242915',
#   'pDate': '2025-02-27 08:00:00',
#   'title': "경복대학교 대학일자리플러스센터, 졸업생 위한 '찾아가는 센터 홍보' ..."},
#  {'cnt': 990,
#   'description': '충주문화시니어클럽은 올해 총 17개 사업단을 운영할 계획이며, 공익활동 사업 718명, 노인 역량 활용 사업 100명, 공동체 사업단 70명, <b>취업</b> 지원 75명 등 총 963명의 노인이 참여하게 된다. 박보경 관장은 &quot;어르신들의... ',
#   'link': 'http://www.queen.co.kr/news/articleView.html?idxno=428977',
#   'org_link': 'http://www.queen.co.kr/news/articleView.html?idxno=428977',
#   'pDate': '2025-02-27 08:00:00',
#   'title': '충주시, 노인일자리 활성화를 위한 충주문화시니어클럽 개소하다'},
#  {'cnt': 991,
#   'description': "특히, 올해는 외국인 유학생들에게 졸업 후 <b>취업</b>이 보장되는 맞춤형 교육과정인 IT·기계 분야 '국제주문식협약반'을 신규로 개설해 실질적인 <b>취업</b> 지원을 강화한다. 영진전문대는 IEQAS 평가 인증과 함께 교육부... ",
#   'link': 'https://www.startuptoday.co.kr/news/articleView.html?idxno=412297',
#   'org_link': 'https://www.startuptoday.co.kr/news/articleView.html?idxno=412297',
#   'pDate': '2025-02-27 08:00:00',
#   'title': '영진전문대, 8년 연속 교육국제화역량 인증대학 선정'},
#  {'cnt': 992,
#   'description': '이 사업은 <b>취업</b>과 창업을 준비하는 청년과 중소기업 근로자를 위한 맞춤형 주거 공간으로, <b>취업</b>지원 라운지와 공유 오피스 등 특화시설이 함께 조성될 예정이다. 2026년 착공, 2029년 준공을 목표로 추진된다. 원도심... ',
#   'link': 'https://www.goodmorningcc.com/news/articleView.html?idxno=415803',
#   'org_link': 'https://www.goodmorningcc.com/news/articleView.html?idxno=415803',
#   'pDate': '2025-02-27 07:58:00',
#   'title': '대전시, 청년·신혼부부 주택 2만 호 공급'},
#  {'cnt': 993,
#   'description': '한국내 <b>취업</b>시장이 어렵다고 하지만 그래도 한국의 기업법무나 아니면 한국 송무 이런 거를 좀 거치고... 한국 내에서도 외국 로펌 <b>취업</b>이 좀 자유롭게, 우수한 인재들을 활용할 수 있는 규제적인 측면을 조금 풀어줘야... ',
#   'link': 'http://www.legaltimes.co.kr/news/articleView.html?idxno=84707',
#   'org_link': 'http://www.legaltimes.co.kr/news/articleView.html?idxno=84707',
#   'pDate': '2025-02-27 07:58:00',
#   'title': "[커버스토리] 'K-Legal의 프런티어' 특별좌담"},
#  {'cnt': 994,
#   'description': '이 사업은 미<b>취업</b> 졸업생, 이른바 ‘쉬었음 청년’을 예방하기 위해 고용노동부가 올해 신설한 사업이다.... 이를 바탕으로 미<b>취업</b> 졸업생 발굴 체계를 구축하고, 졸업생 사후관리를 강화하며, 보다 체계적인 <b>취업</b> 지원... ',
#   'link': 'http://www.withinnews.co.kr/news/view.html?section=1&category=155&item=&no=35732',
#   'org_link': 'http://www.withinnews.co.kr/news/view.html?section=1&category=155&item=&no=35732',
#   'pDate': '2025-02-27 07:54:00',
#   'title': '삼육대, 고용노동부 ‘졸업생 특화 프로그램’ 운영대학 선정'},
#  {'cnt': 995,
#   'description': '금융감독원 전자공시와 <b>취업</b>포털사이트, 블라인드 등의 자료에 따르면 세전 기준으로 정규직 신입사원... <b>취업</b>을 앞둔 우리나라 학생들이 가장 원하는 목표는 단연 대기업이었습니다. 비누랩스 인사이트가 지난해... ',
#   'link': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1008000510&plink=ORI&cooper=NAVER',
#   'org_link': 'https://news.sbs.co.kr/news/endPage.do?news_id=N1008000510&plink=ORI&cooper=NAVER',
#   'pDate': '2025-02-27 07:47:00',
#   'title': '한국 대기업 신입 연봉은 세계 최고 수준이다?'},
#  {'cnt': 996,
#   'description': '또 ▲맞춤형 인재 양성을 위한 교육과정 개발 및 인프라 공동 활용 ▲기업 수요 맞춤형 인재 양성과 재직자 교육 지원 청년 일자리 창출 및 <b>취업</b>·창업 지원 등 다양한 분야에서 상생 발전을 도모할 계획이다. 이병운... ',
#   'link': 'http://kpenews.com/View.aspx?No=3555803',
#   'org_link': 'http://kpenews.com/View.aspx?No=3555803',
#   'pDate': '2025-02-27 07:36:00',
#   'title': '국립순천대, 애니메이션·문화콘텐츠산업 성장 이끈다..로커스와 업무협...'},
#  {'cnt': 997,
#   'description': "기존 연차를 포기하고라도 다른 기업에 <b>취업</b>하려는 사람들을 위한 것이라는 설명이다. 해당 채용 공고가... 임원 선발 기회와 정년 퇴직 후 최대 2년간 재고용될 수 있는 점도 <b>취업</b> 준비생들 사이에서 '킹산직'으로 불리는... ",
#   'link': 'https://www.newswhoplus.com/news/articleView.html?idxno=21833',
#   'org_link': 'https://www.newswhoplus.com/news/articleView.html?idxno=21833',
#   'pDate': '2025-02-27 07:36:00',
#   'title': "포스코, '중고 신입' 채용 논란...임금절감 꼼수?"},
#  {'cnt': 998,
#   'description': '송하철 총장은 환영사에서 “전남 지역의 다양한 기관들이 국제화 사업, 해외 <b>취업</b>, 외국인력 수급 문제 해결을 위해 협력체계를 구축하여 인구 소멸 문제를 해결하고, 외국인에게 높은 만족도를 제공하는 프로그램을... ',
#   'link': 'https://www.geconomy.co.kr/news/article.html?no=295067',
#   'org_link': 'https://www.geconomy.co.kr/news/article.html?no=295067',
#   'pDate': '2025-02-27 07:32:00',
#   'title': '전남 국제화의 중심, 국립목포대가 이끈다...&quot;글로벌 종합지원센터 개편...'},
#  {'cnt': 999,
#   'description': '지역 기업 <b>취업</b>을 희망하는 학생을 사전 선발해 123명의 학생이 기업 맞춤형 직무교육 과정을 이수하고, 8개 기업에 최종 합격하는 쾌거를 이뤘다.이번에 연장에 따라 도는 최대 3년간 특별교부금 7억 5천만원을... ',
#   'link': 'https://www.yeongnam.com/web/view.php?key=20250226010003368',
#   'org_link': 'https://www.yeongnam.com/web/view.php?key=20250226010003368',
#   'pDate': '2025-02-27 07:30:00',
#   'title': '경북도 &quot;고졸 기술인재 양성 3년 더&quot;'},
#  {'cnt': 1000,
#   'description': '<b>취업</b> 정보까지, 맞춤형 진로 탐색의 장 열려 사진|원주시청 [스포츠서울ㅣ원주=김기원기자]원주시는 교육발전특구 연계사업의 일환으로, 지난 25일(화) 원주교육문화관 1층 대강당에서 DREAM ON ‘내 꿈을 켜다’ 진로·<b>취업</b>... ',
#   'link': 'https://www.sportsseoul.com/news/read/1497558?ref=naver',
#   'org_link': 'https://www.sportsseoul.com/news/read/1497558?ref=naver',
#   'pDate': '2025-02-27 07:20:00',
#   'title': '원주시, DREAM ON ‘내 꿈을 켜다’ 진로·<b>취업</b> 토크콘서트 성료'}]

# %%
# 해당 데이터에서, 기사 내용인 , message 부분의 값 추출 작업. 
# 임시 저장 문자열
message = ""
# data = [{딕션너리1},{딕션너리2},{딕션너리3},...]
for item in data:
  # if "message" in item.keys():
  if "description" in item.keys():
    # (\w : 문자, 숫자 의미 ) 앞에 ^(not) 가 아닌 것은 모두 -> 공백으로 변경함.
    # 하나의 임시 메세지 문자열 변수에 담기
    message = message + re.sub(r"[^\w]"," ", item["description"]) + ""
    # message = message + re.sub(r"[^\w]"," ", item["message"]) + ""
message
# Out:
# '경기도에서 한식당을 운영하는 외식업주의 자녀 최 모 양은  quot 우아한 사장님 자녀 장학금 덕분에 무리한 아르바이트 없이  b 취업  b  준비에 전념할 수 있었고 원하는 결과를 이룰 수 있었다 quot 며 소감을 전했다  기존에는    경기도에서 한식당을 운영하는 외식업주의 자녀 최 모 양은  quot 우아한 사장님 자녀 장학금 덕분에 무리한 아르바이트 없이  b 취업  b  준비에 전념할 수 있었고 원하는 결과를 이룰 수 있었다 quot 며 소감을 전했다  기존에는    노인 돌봄을 위한 외국인 간호조무사들의 국내  b 취업  b  허용 등도 제안했다  이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양  간호  호스피스 등을 위한 간호조무사를 양성하고 있다  이    경남 김해 지역의 청년 고용률 향상에 이바지하는 한편  젊은 세대의  b 취업  b  안정과 경제 활동에 기여할 것으로 예상된다  지역 소상공인 제품 매입 확대를 통한 지역 경제 활성화 효과도 기대된다  쿠팡은 지역 소상공인    또 외국인 유학생만을 위한  b 취업  b 박람회도 개최하고 유학생의 안정적 생활과 지역사회와의 유대감 강화 및 정착을 돕는 유학생 후견인 시스템인  K 가디언 제도 를 운영하고 있다  유학생이 아닌 결혼이민자들을 위한    이같은 선발계획은 기존 몽골  베트남 등에서 유입된 이주배경 학생들에게 보다 체계적인 직업교육의 기회를 제공하며  안정적인 교육과  b 취업  b 을 통해 미래를 설계할 수 있도록 지원한다는 뜻을 담고 있다  특히  이주배경    또한  국민은행은 교육생들에게  자기주도학습비 지원  1대1  b 취업  b  컨설팅 및 특강  현직자와 함께하는 금융 프로젝트 및  b 취업  b  멘토링  코딩테스트 대비반 운영  국내 연수 및 힐링캠프   b 취업  b 준비패키지    전문인력양성사업  b 취업  b 연계형 특성화과정  에 2년 연속 선정되는 쾌거를 이뤘다  이 사업은    이 사업을 통해 대학원생들에게 장학금 혜택과 함께 지역 기업들과의  b 취업  b 연계 프로그램을 운영해 왔다  특히 지난해에는      2024 주요노동판례  개별적 근로관계 근로자성  근로시간  임금  징계 및 해고   b 취업  b 규칙 등 와 집단적 노사관계 공정대표의무  노동조합  노조법상 근로자  단체교섭 및 단체협약  부당노동행위 등   비정규직    노인 돌봄을 위한 외국인 간호조무사들의 국내  b 취업  b  허용 등도 제안했다  이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양  간호  호스피스 등을 위한 간호조무사를 양성하고 있다  이    이 밖에도 노인 돌봄을 위한 외국인 간호조무사들의 국내  b 취업  b  허용 등도 제안했다  이 회장은 현재 라오스와 캄보디아 등 동남아에 간호대학을 설립해 노인요양  간호  호스피스 등을 위한 간호조무사를 양성하고 있다     우선 신규 인력 유입과 관련해 고용부는 청년과 여성  중장년을 대상으로 한 맞춤형  b 취업  b  정보를 제공한다는 계획이다  현재 건설업  b 취업  b 자 절반 이상인 55 2 가 50세 이상을 기록하는 등 고령화로 인해 신규 인력 투입이    기아자동차 광주공장에서 또 다시  b 취업  b 을 미끼로 한 사기 의혹이 불거졌다  오랜 경기침체로 많은 기업들이 투자를 줄이면서 구직시장이 갈수록 줄어드는 상황에서 구직자의 절박한 심정을 악용하는  b 취업  b 사기는    한수원은 초록우산 어린이재단과 협업을 통해 자립준비청년들이 성공적으로 사회에 정착할 수 있도록 기초학습  인턴십  자립수당   b 취업  b 축하금 및  b 취업  b 지원비 등 자립 단계에 맞는 맞춤형 프로그램을 지원하고 있다  이    선관위  대규모  b 취업  b  청탁  quot 고위직 자녀 공무원에 채용 quot  선거관리위원회가 지난 10여 년 동안 고위직 인사의 자녀를 비공개 채용하거나 면접 점수를 위조하며 채용 비리에 나섰던 사실이 감사원 감사 결과 드러났습니다     경남 김해 지역의 청년 고용률 향상에 이바지하는 한편  젊은 세대의  b 취업  b  안정과 경제 활동에 기여할 것으로 예상된다  지역 소상공인 제품 매입 확대를 통한 지역 경제 활성화 효과도 기대된다  쿠팡은 지역 소상공인     b 취업  b 은 본인이 하는 것이지만 혼자하기에는 외롭고  고단하고  스트레스를 많이 받는다  경제적으로도 힘들고    5년이상 복무한 제대군인은 전역일 상관없이 제대군인지원센터에서  b 취업  b 을 위한 도움을 받기를 바란다     관련  b 취업  b 자도 급감하고 있다  공제회는 지난달 건설업  b 취업  b 자가 192만1 000명으로  전년 동월 대비 8 1 나 준 것으로 추산했다  이 중 사무 판매 직무 등을 제외한 건설 현장 육체노동 종사자 기능원 장치기계조작 및    향상시키고  b 취업  b  경쟁력을 높이기 위해 2022년부터 지속적으로 운영되고 있다  특히 고용노동부가    KB국민은행은 참가자들에게  자기주도학습비 지원  1대1  b 취업  b  컨설팅 및 특강  금융권 현직자와    한국마사회는 지난해 8월  청년들에게 양질의 일자리 제공과  b 취업  b  실무 역량을 배양하기 위해 35명을    청년들의  b 취업  b  역량 개발과 실무적 이해도 향상에 도움이 될 수 있도록 노력하겠다 quot 고 밝혔다  한국마사회는    맞춤형  b 취업  b  성과 돋보여 전라남도교육청 소속 직업계고와 마이스터고 졸업 예정 생 800여 명이 2024년도 공공기관  대기업  금융기관  공무원 등 주요 기관 및 기업에  b 취업  b 한 것으로 집계됐다  27일 전라남도교육청    이 사업은  b 취업  b 과 창업을 준비하는 청년과 중소기업 근로자를 위한 맞춤형 주거 공간으로   b 취업  b 지원 라운지와 공유 오피스 등 특화시설이 함께 조성될 예정이다  2026년 착공  2029년 준공을 목표로 추진된다  또한    이번 사업 선정으로 평택대학교는 졸업 후 2년 이내 미 b 취업  b 자 지역 내 미 b 취업  b  청년을 대상으로 맞춤형  b 취업  b  지원을 제공하게 된다  취창업지원단을 중심으로 구직자의 노동시장 진입을 돕고  지역 기업과의 협력    해외 b 취업  b  및 이민 설명회 를 온라인 화상회의 플랫폼 ZOOM 을 통해 개최했다  이번 설명회는 제대군인의 해외  b 취업  b  이민 기회를 확대하기 위한 목적으로 기획됐다  캐나다 각 주별 비자 제도와  b 취업  b  가능 직종  이민 절차    또 A 씨에게 가정폭력 치료프로그램 40시간 이수와 아동학대 치료프로그램 40시간 이수  아동 관련 기관 5년간  b 취업  b 제한도 명령했다  A 씨는 2019년 4월부터 지난해 8월까지 경남 김해시 주촌면 주거지 등에서 아내 B 씨    HD현대1 나눔재단 이사장 권오갑 이 화가를 꿈꾸는 장애인들의 성장을 돕고 있다  HD현대1 나눔재단은 권오갑 이사장을 비롯한 재단 이사진이 27일 서울 강동구에 위치한 대한사회복지회  마스터피스제작소  사업장을     b 취업  b  후 상환하는 학자금대출의 금리 상한을 매 학기 시작 전 국채 3년간 평균 수익률 120 에서 110 로 조정하는 내용의   b 취업  b  후 학자금 상환 특별법 도 본회의 문턱을 넘었습니다  대학교원 신규 채용 시 임용권자가     조선업 신규  b 취업  b 자 이주 정착비 지원 거제시가 조선업 신규  b 취업  b 자에게 이주 정착비를 월 30만원씩 최대 1년간 지원한다  지원 대상은 조선업체에 신규  b 취업  b 한 근로자로  지난 2023년 1월1일 이후 경남 외 지역에서    사진 리멤버앤컴퍼니 이번 캠페인은 장기화된  b 취업  b 난 속에 지친  b 취업  b 준비생들의 상반기 신입 공채 최종 합격에 실질적인 도움을 주고자 마련됐다  자소설닷컴이 취준생들의 서류 인적성 면접 등 채용 전형에 어려운    간호조무사  b 취업  b  허용 제안  아시아타임즈 이재성 기자  이중근 부영그룹 회장이 저출산    노인 돌봄을 위한 외국인 간호조무사들의 국내  b 취업  b  허용 등도 제안했다  이 회장은 현재 라오스 ...

# %%
# 품사 태깅, Okt 패키지 사용하기. 
nlp = Okt()
message_N = nlp.nouns(message)
message_N
# Out:
# ['경기도',
#  '한식당',
#  '운영',
#  '외식',
#  '업주',
#  '자녀',
#  '최',
#  '모',
#  '양은',
#  '사장',
#  '자녀',
#  '장학금',
#  '덕분',
#  '아르바이트',
#  '취업',
#  '준비',
#  '전념',
#  '수',
#  '결과',
#  '수',
#  '며',
#  '소감',
#  '전',
#  '기존',
#  '경기도',
#  '한식당',
#  '운영',
#  '외식',
#  '업주',
#  '자녀',
#  '최',
#  '모',
#  '양은',
#  '사장',
#  '자녀',
#  '장학금',
#  '덕분',
#  '아르바이트',
#  '취업',
#  '준비',
#  '전념',
#  '수',
#  '결과',
#  '수',
#  '며',
#  '소감',
#  '전',
#  '기존',
#  '노인',
#  '위',
#  '외국인',
#  '간호조무사',
#  '국내',
#  '취업',
#  '허용',
#  '등',
#  '제안',
#  '이',
#  '회장',
#  '현재',
#  '라오스',
#  '캄보디아',
#  '등',
#  '동남아',
#  '간호',
#  '대학',
#  '설립',
#  '노인',
#  '요양',
#  '간호',
#  '호스피스',
#  '등',
#  '위',
#  '간호조무사',
#  '양성',
#  '이',
#  '경남',
#  '김해',
#  '지역',
#  '청년',
#  '고용',
#  '률',
#  '향상',
#  '이바지',
#  '한편',
#  '세대',
#  '취업',
#  '안정',
#  '경제',
#  '활동',
#  '기여',
#  '것',
#  '예상',
#  '지역',
#  '소상',
#  '공인',
#  '제품',
#  '매입',
#  '확대',
#  '통한',
#  '지역',
#  '경제',
#  '활성화',
#  '효과',
#  '기대',
#  '쿠팡',
#  '지역',
#  '소상',
#  '공인',
#  '또',
#  '외국인',
#  '유학생',
#  '위',
#  '취업',
#  '박람회',
#  '개최',
#  '유학생',
#  '안정',
#  '생활',
#  '지역',
#  '사회',
#  '유',
#  '대감',
#  '강화',
#  '및',
#  '정착',
#  '유학생',
#  '후견인',
#  '시스템',
#  '가디언',
#  '제도',
#  '를',
#  '운영',
#  '유학생',
#  '결혼',
#  '이민자',
#  '위',
#  '이',
#  '선발',
#  '계획',
#  '기존',
#  '몽골',
#  '베트남',
#  '등',
#  '유입',
#  '이주',
#  '배경',
#  '학생',
#  '체계',
#  '직업',
#  '교육',
#  '기회',
#  '제공',
#  '안정',
#  '교육',
#  '취업',
#  '통해',
#  '미래',
#  '설계',
#  '수',
#  '뜻',
#  '이주',
#  '배경',
#  '또한',
#  '국민은행',
#  '교육',
#  '생',
#  '자기',
#  '주도',
#  '학습',
#  '비',
#  '지원',
#  '취업',
#  '컨설팅',
#  '및',
#  '특강',
#  '현직',
#  '금융',
#  '프로젝트',
#  '및',
#  '취업',
#  '멘토링',
#  '코딩',
#  '테스트',
#  '대비',
#  '반',
#  '운영',
#  '국내',
#  '연수',
#  '및',
#  '힐링캠프',
#  '취업',
#  '준비',
#  '패키지',
#  '전문',
#  '인력',
#  '양성',
#  '사업',
#  '취업',
#  '계',
#  '특성',
#  '과정',
#  '연속',
#  '선정',
#  '쾌거',
#  '이',
#  '사업',
#  '이',
#  '사업',
#  '통해',
#  '대학원생',
#  '장학금',
#  '혜택',
#  '지역',
#  '기업',
#  '취업',
#  '계',
#  '프로그램',
#  '운영',
#  '지난해',
#  '노동',
#  '판례',
#  '개별',
#  '근로',
#  '관계',
#  '근로자',
#  '근로시간',
#  '임금',
#  '징계',
#  '및',
#  '해고',
#  '취업',
#  '규칙',
#  '등',
#  '집단',
#  '노사',
#  '관계',
#  '공정',
#  '대표',
#  '의무',
#  '노동조합',
#  '노조',
#  '법',
#  '근로자',
#  '단체교섭',
#  '및',
#  '단체',
#  '협약',
#  '부당',
#  '노동',
#  '행위',
#  '등',
#  '비정규직',
#  '노인',
#  '위',
#  '외국인',
#  '간호조무사',
#  '국내',
#  '취업',
#  '허용',
#  '등',
#  '제안',
#  '이',
#  '회장',
#  '현재',
#  '라오스',
#  '캄보디아',
#  '등',
#  '동남아',
#  '간호',
#  '대학',
#  '설립',
#  '노인',
#  '요양',
#  '간호',
#  '호스피스',
#  '등',
#  '위',
#  '간호조무사',
#  '양성',
#  '이',
#  '이',
#  '노인',
#  '위',
#  '외국인',
#  '간호조무사',
#  '국내',
#  '취업',
#  '허용',
#  '등',
#  '제안',
#  '이',
#  '회장',
#  '현재',
#  '라오스',
#  '캄보디아',
#  '등',
#  '동남아',
#  '간호',
#  '대학',
#  '설립',
#  '노인',
#  '요양',
#  '간호',
#  '호스피스',
#  '등',
#  '위',
#  '간호조무사',
#  '양성',
#  '우선',
#  '신규',
#  '인력',
#  '유입',
#  '관련',
#  '고용부',
#  '청년',
#  '여성',
#  '중장',
#  '년',
#  '대상',
#  '맞춤',
#  '취업',
#  '정보',
#  '계획',
#  '현재',
#  '건설업',
#  '취업',
#  '자',
#  '절반',
#  '이상인',
#  '세',
#  '이상',
#  '기록',
#  '등',
#  '고령화',
#  '신규',
#  '인력',
#  '투입',
#  '기아',
#  '자동차',
#  '광주',
#  '공장',
#  '또',
#  '다시',
#  '취업',
#  '미끼',
#  '사기',
#  '의혹',
#  '침체',
#  '기업',
#  '투자',
#  '직시',
#  '갈수록',
#  '상황',
#  '구직',
#  '자의',
#  '절박',
#  '심정',
#  '악용',
#  '취업',
#  '사기',
#  '한수원',
#  '초록',
#  '우산',
#  '어린이재단',
#  '협업',
#  '통해',
#  '자립',
#  '준비',
#  '청년',
#  '성공',
#  '사회',
#  '정착',
#  '수',
#  '기초',
#  '학습',
#  '인턴십',
#  '자립',
#  '수당',
#  '취업',
#  '축하',
#  '금',
#  '및',
#  '취업',
#  '지원',
#  '비',
#  '등',
#  '자립',
#  '단계',
#  '맞춤',
#  '프로그램',
#  '지원',
#  '이',
#  '선관위',
#  '대규모',
#  '취업',
#  '청탁',
#  '고위',
#  '직',
#  '자녀',
#  '공무원',
#  '채용',
#  '선거',
#  '관리',
#  '위원회',
#  '지난',
#  '여',
#  '년',
#  '동안',
#  '고위',
#  '직',
#  '인사',
#  '자녀',
#  '비공개',
#  '채용',
#  '거나',
#  '면접',
#  '점수',
#  '위조',
#  '채용',
#  '비리',
#  '사실',
#  '감사원',
#  '감사',
#  '결과',
#  '경남',
#  '김해',
#  '지역',
#  '청년',
#  '고용',
#  '률',
#  '향상',
#  '이바지',
#  '한편',
#  '세대',
#  '취업',
#  '안정',
#  '경제',
#  '활동',
#  '기여',
#  '것',
#  '예상',
#  '지역',
#  '소상',
#  '공인',
#  '제품',
#  '매입',
#  '확대',
#  '통한',
#  '지역',
#  '경제',
#  '활성화',
#  '효과',
#  '기대',
#  '쿠팡',
#  '지역',
#  '소상',
#  '공인',
#  '취업',
#  '은',
#  '본인',
#  '것',
#  '혼자',
#  '외',
#  '고단',
#  '스트레스',
#  '경제',
#  '복무',
#  '군인',
#  '전역',
#  '일',
#  '군인',
#  '지원',
#  '센터',
#  '취업',
#  '위',
#  '도움',
#  '관련',
#  '취업',
#  '자도',
#  '급감',
#  '회',
#  '지난달',
#  '건설업',
#  '취업',
#  '자가',
#  '명',
#  '년',
#  '동월',
#  '대비',
#  '나',
#  '준',
#  '것',
#  '추산',
#  '이',
#  '중',
#  '사무',
#  '판매',
#  '직무',
#  '등',
#  '제외',
#  '건설',
#  '현장',
#  '육체노동',
#  '종사',
#  '기능',
#  '장치기',
#  '조작',
#  '및',
#  '향상',
#  '취업',
#  '경쟁력',
#  '위해',
#  '지속',
#  '운영',
#  '고용노동부',
#  '국민은행',
#  '참가자',
#  '자기',
#  '주도',
#  '학습',
#  '비',
#  '지원',
#  '취업',
#  '컨설팅',
#  '및',
#  '특강',
#  '금융',
#  '현직',
#  '한국',
#  '마사회',
#  '지난해',
#  '청년',
#  '양질',
#  '일자리',
#  '제공',
#  '취업',
#  '실무',
#  '역량',
#  '배양',
#  '위해',
#  '명',
#  '청년',
#  '취업',
#  '역량',
#  '개발',
#  '실무',
#  '이해도',
#  '향상',
#  '도움',
#  '수',
#  '노력',
#  '고',
#  '한국',
#  '마사회',
#  '맞춤',
#  '취업',
#  '성과',
#  '전라남도교육청',
#  '소속',
#  '직업',
#  '계고',
#  '마이스터고',
#  '졸업',
#  '예정',
#  '생',
#  '여',
#  '명',
#  '공공기관',
#  '대기업',
#  '금융기관',
#  '공무원',
#  '등',
#  '주요',
#  '기관',
#  '및',
#  '기업',
#  '취업',
#  '것',
#  '집계',
#  '전라남도교육청',
#  '이',
#  '사업',
#  '취업',
#  '과',
#  '창업',
#  '준비',
#  '청년',
#  '중소기업',
#  '근로자',
#  '위',
#  '맞춤',
#  '주거',
#  '공간',
#  '취업',
#  '지원',
#  '라운지',
#  '공유',
#  '오피스',
#  '등',
#  '특',
#  '시설',
#  '조성',
#  '예정',
#  '착공',
#  '준공',
#  '목표',
#  '추진',
#  '또한',
#  '이번',
#  '사업',
#  '선정',
#  '평택대학교',
#  '졸업',
#  '후',
#  '이내',
#  '취업',
#  '자',
#  '지역',
#  '내',
#  '취업',
#  '청년',
#  '대상',
#  '맞춤',
#  '취업',
#  '지원',
#  '제공',
#  '취',
#  '창업',
#  '원단',
#  '중심',
#  '구직',
#  '자의',
#  '노동시장',
#  '진입',
#  '지역',
#  '기업',
#  '협력',
#  '해외',
#  '취업',
#  '및',
#  '이민',
#  '설명',
#  '회',
#  '를',
#  '온라인',
#  '화상회의',
#  '플랫폼',
#  '통해',
#  '개최',
#  '이번',
#  '설명',
#  '회',
#  '군인',
#  '해외',
#  '취업',
#  '이민',
#  '기회',
#  '확대',
#  '위',
#  '목적',
#  '기획',
#  '캐나다',
#  '각',
#  '별',
#  '비자',
#  '제도',
#  '취업',
#  '가능',
#  '직종',
#  '이민',
#  '절차',
#  '또',
#  '씨',
#  '가정폭력',
#  '치료',
#  '프로그램',
#  '이수',
#  '아동학대',
#  '치료',
#  '프로그램',
#  '이수',
#  '아동',
#  '관련',
#  '기관',
#  '취업',
#  '제한',
#  '명령',
#  '씨',
#  '지난해',
#  '경남',
#  '김해시',
#  '주촌면',
#  '주거지',
#  '등',
#  '아내',
#  '씨',
#  '현대',
#  '나눔',
#  '재단',
#  '이사장',
#  '권오갑',
#  '이',
#  '화가',
#  '장애인',
#  '성장',
#  '현대',
#  '나눔',
#  '재단',
#  '권오갑',
#  '이사장',
#  '비롯',
#  '재단',
#  '사진',
#  '서울',
#  '강동구',
#  '위치',
#  '회복',
#  '회',
#  '마스터피스',
#  '제작',
#  '소',
#  '사업',
#  '취업',
#  '후',
#  '상환',
#  '학자금대출',
#  '금리',
#  '상한',
#  '매',
#  '학기',
#  '시작',
#  '전',
#  '국채',
#  '평균',
#  '수익률',
#  '로',
#  '조정',
#  '내용',
#  '취업',
#  '후',
#  '학자금',
#  '상환',
#  '특별법',
#  '도',
#  '본회의',
#  '문턱',
#  '대학교',
#  '신규',
#  '채용',
#  '시',
#  '임용',
#  '자가',
#  '조선업',
#  '신규',
#  '취업',
#  '자',
#  '이주',
#  '정착',
#  '비',
#  '지원',
#  '거제시',
#  '조선업',
#  '신규',
#  '취업',
#  '자',
#  '이주',
#  '정착',
#  '비',
#  '월',
#  '최대',
#  '지원',
#  '지원',
#  '대상',
#  '조선',
#  '업체',
#  '신규',
#  '취업',
#  '근로자',
#  '지난',
#  '이후',
#  '경남',
#  '외',
#  '지역',
#  '사진',
#  '리멤버',
#  '앤',
#  '컴퍼니',
#  '이번',
#  '캠페인',
#  '장기',
#  '취업',
#  '난',
#  '속',
#  '취업',
#  '준비',
#  '생',
#  '상반기',
#  '신입',
#  '공채',
#  '최종',
#  '합격',
#  '실질',
#  '도움',
#  '고자',
#  '마련',
#  '자',
#  '소설',
#  '취준생들',
#  '서류',
#  '인적',
#  '면접',
#  '등',
#  '채용',
#  '전형',
#  '간호조무사',
#  '취업',
#  '허용',
#  '제안',
#  '아시아',
#  '타임즈',
#  '이재성',
#  '기자',
#  '이중근',
#  '부영',
#  '그룹',
#  '회장',
#  '저출산',
#  '노인',
#  '위',
#  '외국인',
#  '간호조무사',
#  '국내',
#  '취업',
#  '허용',
#  '등',
#  '제안',
#  '이',
#  '회장',
#  '현재',
#  '라오스',
#  '캄보디아',
#  '등',
#  '동남아',
#  '취업',
#  '후',
#  '상환',
#  '학자금대출',
#  '금리',
#  '상한',
#  '매',
#  '학기',
#  '시작',
#  '전',
#  '국채',
#  '평균',
#  '수익률',
#  '로',
#  '조정',
#  '내용',
#  '취업',
#  '후',
#  '학자금',
#  '상환',
#  '특별법',
#  '도',
#  '국회',
#  '본회의',
#  '통과',
#  '또한',
#  '아동',
#  '청소년',
#  '착취',
#  '물',
#  '등',
#  '유포',
#  '서산',
#  '나래',
#  '원장',
#  '박정은',
#  '주관',
#  '발달장애',
#  '재능',
#  '사업',
#  '은',
#  '지난',
#  '공사',
#  '후원',
#  '운영',
#  '현재',
#  '총',
#  '명의',
#  '제과제빵',
#  '양성',
#  '이',
#  '중',
#  '명',
#  '취업',
#  '발달장애',
#  '직업',
#  '역량',
#  '취업',
#  '정보',
#  '제공',
#  '그',
#  '결과',
#  '연속',
#  '우수',
#  '사례',
#  '선정',
#  '총',
#  '명의',
#  '금융감독원장',
#  '표창',
#  '배출',
#  '강',
#  '재훈',
#  '저축은행',
#  '감사',
#  '팀',
#  '사',
#  '교',
#  '금융',
#  '교육',
#  '강사',
#  '자발',
#  '참여',
#  '사회',
#  '초년',
#  '생',
#  '금융',
#  '사',
#  '취업',
#  '저축은행',
#  '지난',
#  '지역',
#  '내',
#  '특성화고',
#  '교인',
#  '분당',
#  '영고',
#  '사',
#  '교',
#  '금융',
#  '교육',
#  '자매',
#  '결연',
#  '학생',
#  '금융',
#  '지식',
#  '교육',
#  '금융',
#  '취업',
#  '정보',
#  '제공',
#  '직원',
#  '자발',
#  '교육',
#  '봉사',
#  '참여',
#  '동문',
#  '대학생',
#  '학자금',
#  '대출',
#  '부담',
#  '완화',
#  '위',
#  '취업',
#  '후',
#  '학자금',
#  '상환',
#  '특별법',
#  '개정안',
#  '통과',
#  '금리',
#  '상한',
#  '매',
#  '학기',
#  '시작',
#  '전',
#  '국채',
#  '평균',
#  '수익률',
#  '로',
#  '연체',
#  '금',
#  '한도',
#  '미납',
#  '대출',
#  '원리금',
#  '요양원',
#  '가정',
#  '가족',
#  '임종',
#  '수',
#  '간병인',
#  '도우미',
#  '지원',
#  '확대',
#  '외국인',
#  ...]

# %%
# 집계 데이터 기본 탐색, 모델 구축 하기. 
count = Counter(message_N)
count
# Out:
# Counter({'취업': 1653,
#          '청년': 521,
#          '등': 425,
#          '지원': 374,
#          '지역': 343,
#          '수': 232,
#          '이': 230,
#          '준비': 225,
#          '사업': 221,
#          '것': 202,
#          '교육': 194,
#          '위': 178,
#          '및': 177,
#          '명': 168,
#          '위해': 161,
#          '경제': 155,
#          '일자리': 155,
#          '제공': 153,
#          '맞춤': 148,
#          '프로그램': 144,
#          '기업': 142,
#          '센터': 136,
#          '운영': 131,
#          '대학': 127,
#          '생': 121,
#          '고용': 117,
#          '률': 112,
#          '통해': 112,
#          '한국': 111,
#          '활동': 108,
#          '기관': 108,
#          '역량': 107,
#          '세': 102,
#          '이번': 102,
#          '금융': 99,
#          '분야': 99,
#          '확대': 97,
#          '향상': 92,
#          '관련': 91,
#          '대상': 91,
#          '창업': 91,
#          '공인': 87,
#          '학생': 87,
#          '소상': 86,
#          '고': 86,
#          '이상': 83,
#          '개': 81,
#          '근로자': 80,
#          '자': 80,
#          '계': 78,
#          '구직': 74,
#          '를': 72,
#          '노인': 71,
#          '사회': 71,
#          '채용': 70,
#          '안정': 69,
#          '비': 69,
#          '진로': 69,
#          '외국인': 68,
#          '경남': 68,
#          '상담': 68,
#          '올해': 67,
#          '산업': 66,
#          '자녀': 63,
#          '추진': 63,
#          '장애인': 62,
#          '한편': 61,
#          '과': 61,
#          '시설': 61,
#          '사': 61,
#          '며': 60,
#          '활성화': 60,
#          '목표': 60,
#          '주택': 60,
#          '효과': 59,
#          '주거': 59,
#          '김해': 58,
#          '기여': 58,
#          '전': 57,
#          '신규': 57,
#          '중소기업': 57,
#          '로': 57,
#          '강화': 56,
#          '과정': 56,
#          '광주': 56,
#          '쿠팡': 55,
#          '직업': 55,
#          '세대': 54,
#          '지난해': 54,
#          '경쟁력': 54,
#          '인재': 54,
#          '결과': 52,
#          '이바지': 52,
#          '예상': 52,
#          '제품': 52,
#          '선정': 51,
#          '지난': 51,
#          '후': 51,
#          '통한': 50,
#          '자립': 49,
#          '참여': 49,
#          '처': 49,
#          '진행': 48,
#          '재직': 48,
#          '아동': 47,
#          '매입': 46,
#          '기회': 46,
#          '정보': 46,
#          '밥': 46,
#          '층': 46,
#          '기대': 45,
#          '여성': 45,
#          '사기': 45,
#          '예정': 45,
#          '날': 45,
#          '특': 44,
#          '학교': 44,
#          '제한': 43,
#          '국내': 42,
#          '인구': 42,
#          '졸업생': 42,
#          '중': 41,
#          '여행': 41,
#          '양성': 40,
#          '협력': 40,
#          '실질': 40,
#          '행사': 40,
#          '또': 39,
#          '계획': 39,
#          '시': 39,
#          '결혼': 38,
#          '조성': 38,
#          '경험': 38,
#          '창': 38,
#          '장학금': 37,
#          '간호조무사': 37,
#          '정착': 37,
#          '협약': 37,
#          '년': 37,
#          '공장': 37,
#          '공간': 37,
#          '공유': 37,
#          '해': 37,
#          '계층': 37,
#          '제안': 36,
#          '현장': 36,
#          '라운지': 36,
#          '오피스': 36,
#          '서울': 36,
#          '바탕': 36,
#          '정글': 36,
#          '대표': 35,
#          '최현석': 35,
#          '서비스': 35,
#          '취약': 35,
#          '유학': 35,
#          '기존': 34,
#          '신청': 34,
#          '훈련': 34,
#          '경기도': 33,
#          '외식': 33,
#          '일': 33,
#          '고용노동부': 33,
#          '그': 33,
#          '기간': 33,
#          '기준': 33,
#          '모': 32,
#          '간호': 32,
#          '국제': 32,
#          '글로벌': 32,
#          '국민은행': 31,
#          '준공': 31,
#          '아동학대': 31,
#          '면접': 30,
#          '은': 30,
#          '실무': 30,
#          '주요': 30,
#          '별': 30,
#          '교육과정': 30,
#          '전공': 30,
#          '겸직': 30,
#          '아르바이트': 29,
#          '전문': 29,
#          '착공': 29,
#          '복지': 29,
#          '거주': 29,
#          '이하': 29,
#          '입국': 29,
#          '최': 28,
#          '허용': 28,
#          '회장': 28,
#          '현재': 28,
#          '유학생': 28,
#          '개최': 28,
#          '대기업': 28,
#          '도심': 28,
#          '최근': 28,
#          '평가': 28,
#          '수료': 28,
#          '범죄': 28,
#          '재': 28,
#          '기아차': 28,
#          '대한': 28,
#          '더': 28,
#          '한식당': 27,
#          '업주': 27,
#          '양은': 27,
#          '컨설팅': 27,
#          '연수': 27,
#          '졸업': 27,
#          '씨': 27,
#          '대학생': 27,
#          '수로': 27,
#          '사장': 26,
#          '또한': 26,
#          '해외': 26,
#          '목적': 26,
#          '도': 26,
#          '노하우': 26,
#          '발대식': 26,
#          '과거': 26,
#          '수소': 26,
#          '커리어': 26,
#          '개월': 26,
#          '원': 26,
#          '덕분': 25,
#          '전념': 25,
#          '시스템': 25,
#          '제도': 25,
#          '인력': 25,
#          '임금': 25,
#          '사진': 25,
#          '공사': 25,
#          '직원': 25,
#          '예비': 25,
#          '정도': 25,
#          '셰프': 25,
#          '해당': 25,
#          '활용': 25,
#          '주': 25,
#          '모집': 25,
#          '소감': 24,
#          '성공': 24,
#          '개발': 24,
#          '내': 24,
#          '관세': 24,
#          '적발': 24,
#          '부총': 24,
#          '경력': 24,
#          '관계자': 24,
#          '기술': 24,
#          '어학': 24,
#          '경기': 24,
#          '경영': 24,
#          '박람회': 23,
#          '멘토링': 23,
#          '금': 23,
#          '명령': 23,
#          '업체': 23,
#          '총': 23,
#          '감소': 23,
#          '가장': 23,
#          '희망': 23,
#          '이력': 23,
#          '경찰': 23,
#          '관리': 22,
#          '설명': 22,
#          '팀': 22,
#          '대출': 22,
#          '자산': 22,
#          '형성': 22,
#          '트럼프': 22,
#          '돈': 22,
#          '정부': 22,
#          '말': 22,
#          '자격': 22,
#          '의': 22,
#          '직무': 21,
#          '시작': 21,
#          '약': 21,
#          '지적': 21,
#          '중국': 21,
#          '단': 21,
#          '지능': 21,
#          '병원': 21,
#          '임대주택': 21,
#          '제': 21,
#          '회': 20,
#          '대학교': 20,
#          '이후': 20,
#          '장기': 20,
#          '캠프': 20,
#          '다큐': 20,
#          '경찰청': 20,
#          '근무': 20,
#          '경제위기': 20,
#          '극복': 20,
#          '민생': 20,
#          '설정': 20,
#          '학습': 19,
#          '특성': 19,
#          '여': 19,
#          '지속': 19,
#          '중심': 19,
#          '기획': 19,
#          '상반기': 19,
#          '명의': 19,
#          '플러스': 19,
#          '미식': 19,
#          '발굴': 19,
#          '수사': 19,
#          '환경': 19,
#          '전략': 19,
#          '마약': 19,
#          '공고': 19,
#          '융합': 19,
#          '시간': 19,
#          '혹': 19,
#          '순위': 19,
#          '체계': 18,
#          '건설업': 18,
#          '협업': 18,
#          '특징': 18,
#          '윤남노': 18,
#          '뒤': 18,
#          '군': 18,
#          '학과': 18,
#          '분석': 18,
#          '조사': 18,
#          '응답': 18,
#          '미국': 18,
#          '특강': 17,
#          '마련': 17,
#          '청소년': 17,
#          '금융인': 17,
#          '저': 17,
#          '회사': 17,
#          '시니어': 17,
#          '확인': 17,
#          '본부장': 17,
#          '자신': 17,
#          '인공': 17,
#          '위기': 17,
#          '사항': 17,
#          '정책': 17,
#          '라오스': 16,
#          '캄보디아': 16,
#          '동남아': 16,
#          '설립': 16,
#          '생활': 16,
#          '인턴십': 16,
#          '외': 16,
#          '비자': 16,
#          '비롯': 16,
#          '상환': 16,
#          '가족': 16,
#          '금융업': 16,
#          '페루': 16,
#          '실습': 16,
#          '홍보': 16,
#          '주최': 16,
#          '실장': 16,
#          '경제활동': 16,
#          '모빌리티': 16,
#          '취득': 16,
#          '무': 16,
#          '차': 16,
#          '토지': 16,
#          '벌': 16,
#          '사람인': 16,
#          '요양': 15,
#          '호스피스': 15,
#          '자의': 15,
#          '수당': 15,
#          '마사회': 15,
#          '성장': 15,
#          '내용': 15,
#          '기자': 15,
#          '주관': 15,
#          '우수': 15,
#          '문제': 15,
#          '종별': 15,
#          '소개': 15,
#          '광운대': 15,
#          '스마트': 15,
#          '무료': 15,
#          '부처': 15,
#          '적극': 15,
#          '강의': 15,
#          '관심': 15,
#          '이직': 15,
#          '라며': 15,
#          '총장': 15,
#          '광주시': 15,
#          '다만': 15,
#          '소유자': 15,
#          '급여': 15,
#          '버팀목': 15,
#          '전세': 15,
#          '자금': 15,
#          '처음': 15,
#          '베트남': 14,
#          '관계': 14,
#          '거나': 14,
#          '양질': 14,
#          '각': 14,
#          '회복': 14,
#          '제작': 14,
#          '학자금': 14,
#          '자신감': 14,
#          '경복대': 14,
#          '부과': 14,
#          '스타트업': 14,
#          '공모': 14,
#          '작성': 14,
#          '초청': 14,
#          '용': 14,
#          '예방': 14,
#          '사이': 14,
#          '유발': 14,
#          '김': 14,
#          '시장': 14,
#          '어려움': 14,
#          '빅데이터': 14,
#          '협회': 14,
#          '액': 14,
#          '교육청': 14,
#          '심사': 14,
#          '규제': 14,
#          '보장': 14,
#          '발전': 14,
#          '의미': 14,
#          '특화': 14,
#          '상공': 14,
#          '수입': 14,
#          '사유': 14,
#          '유': 13,
#          '혜택': 13,
#          '단체': 13,
#          '기록': 13,
#          '기아': 13,
#          '자동차': 13,
#          '직': 13,
#          '도움': 13,
#          '노동시장': 13,
#          '최대': 13,
#          '도우미': 13,
#          '물류': 13,
#          '도전': 13,
#          '체험': 13,
#          '전국': 13,
#          '점검': 13,
#          '형사': 13,
#          '부스': 13,
#          '안전': 13,
#          '탁': 13,
#          '수강': 13,
#          '수요': 13,
#          '수원시': 13,
#          '캠퍼스': 13,
#          '진': 13,
#          '자율': 13,
#          '국립': 13,
#          '소득': 13,
#          '일환': 13,
#          '애로': 13,
#          '온': 13,
#          '유혹': 13,
#          '운세': 13,
#          '공식': 13,
#          '중장': 12,
#          '침체': 12,
#          '단계': 12,
#          '종사': 12,
#          '전라남도교육청': 12,
#          '공공기관': 12,
#          '집계': 12,
#          '현대': 12,
#          '재단': 12,
#          '평균': 12,
#          '거제시': 12,
#          '업무': 12,
#          '국민': 12,
#          '단기': 12,
#          '아카데미': 12,
#          '방문': 12,
#          '퇴직': 12,
#          '누구': 12,
#          '전력': 12,
#          '선': 12,
#          '촉진': 12,
#          '대외협력': 12,
#          '이경수': 12,
#          '정처': 12,
#          '이희': 12,
#          '공처': 12,
#          '인권': 12,
#          '조지은': 12,
#          '교무': 12,
#          '최영욱': 12,
#          '입학': 12,
#          '곳': 12,
#          '전망': 12,
#          '문화': 12,
#          '네트워크': 12,
#          '고민': 12,
#          '발표': 12,
#          '전남': 12,
#          '인턴': 12,
#          '순환': 12,
#          '재료': 12,
#          '꿈': 12,
#          '자기': 11,
#          '프로젝트': 11,
#          '반': 11,
#          '연속': 11,
#          '노동': 11,
#          '투자': 11,
#          '기초': 11,
#          '축하': 11,
#          '인사': 11,
#          '건설': 11,
#          '플랫폼': 11,
#          '부담': 11,
#          '체결': 11,
#          '인프라': 11,
#          '통합': 11,
#          '양천구': 11,
#          '달': 11,
#          '가로': 11,
#          '기동대': 11,
#          '체육': 11,
#          '의원': 11,
#          '차례': 11,
#          '입원': 11,
#          '두': 11,
#          '점': 11,
#          '노동자': 11,
#          '데이터': 11,
#          '전북': 11,
#          '약자': 11,
#          '체감': 11,
#          '상권': 11,
#          '인증': 11,
#          '혁신': 11,
#          '변화': 11,
#          '업': 11,
#          '이주': 10,
#          '대비': 10,
#          '노조': 10,
#          '공무원': 10,
#          '마이스터고': 10,
#          '절차': 10,
#          '나눔': 10,
#          '화가': 10,
#          '금리': 10,
#          '상한': 10,
#          '학기': 10,
#          '국채': 10,
#          '수익률': 10,
#          '완화': 10,
#          '에이': 10,
#          '구인': 10,
#          '참석': 10,
#          '여부': 10,
#          '위반': 10,
#          '예산': 10,
#          '군민': 10,
#          '공동체': 10,
#          '못': 10,
#          '콘텐츠': 10,
#          '재범': 10,
#          '소프트웨어': 10,
#          '인원': 10,
#          '참여자': 10,
#          '기반': 10,
#          '디지털': 10,
#          '대해': 10,
#          '숙련': 10,
#          '구축': 10,
#          '학습자': 10,
#          '유형': 10,
#          '산학': 10,
#          '구조': 10,
#          '증가': 10,
#          '학원': 10,
#          '실시': 10,
#          '인생': 10,
#          '복수': 10,
#          '쇠퇴': 10,
#          '순': 10,
#          '이나': 10,
#          '무안군': 10,
#          '군수': 10,
#          '단절': 10,
#          '부천시': 10,
#          '대통령': 10,
#          '법인세': 10,
#          '설계': 9,
#          '규칙': 9,
#          '미끼': 9,
#          '한수원': 9,
#          '초록': 9,
#          '우산': 9,
#          '어린이재단': 9,
#          '배양': 9,
#          '취': 9,
#          '매': 9,
#          '조정': 9,
#          '특별법': 9,
#          '분명': 9,
#          '서울시': 9,
#          '책': 9,
#          '사람': 9,
#          '통계청': 9,
#          '일상': 9,
#          '홈페이지': 9,
#          '공익': 9,
#          '권': 9,
#          '정': 9,
#          '아들': 9,
#          '환': 9,
#          '평택시': 9,
#          '탐색': 9,
#          '앞': 9,
#          '자격증': 9,
#          '세종': 9,
#          '친환경': 9,
#          '고립': 9,
#          '생각': 9,
#          '간부': 9,
#          '동기': 9,
#          '행정': 9,
#          '교통': 9,
#          '장학생': 9,
#          '베트남인': 9,
#          '가담': 9,
#          '돕기': 9,
#          '연합': 9,
#          '시청': 9,
#          '경우': 9,
#          '자료': 9,
#          '여성가족부': 9,
#          '개설': 9,
#          '운영자': 9,
#          '임원': 9,
#          '직접': 9,
#          '현직': 8,
#          '대학원생': 8,
#          '근로': 8,
#          '투입': 8,
#          '지난달': 8,
#          '자가': 8,
#          '나': 8,
#          '노력': 8,
#          '성과': 8,
#          '소속': 8,
#          '금융기관': 8,
#          '진입': 8,
#          '월': 8,
#          '통과': 8,
#          '초년': 8,
#          '종합': 8,
#          '관내': 8,
#          '공동': 8,
#          '오후': 8,
#          '별로': 8,
#          '손': 8,
#          '금품': 8,
#          '모의': 8,
#          '중인': 8,
#          '기업체': 8,
#          '보건복지부': 8,
#          '클럽': 8,
#          '분리': 8,
#          '불법': 8,
#          '핵심': 8,
#          '관': 8,
#          '신입생': 8,
#          '충남대': 8,
#          '통신': 8,
#          '담': 8,
#          '리서치': 8,
#          '접수': 8,
#          '생산': 8,
#          '돌아이': 8,
#          '조치': 8,
#          '배': 8,
#          '참가': 8,
#          '학업': 8,
#          '도내': 8,
#          '중이': 8,
#          '단념': 8,
#          '보증금': 8,
#          '시간제': 8,
#          '우리나라': 8,
#          '공시': 8,
#          '최고': 8,
#          '수준': 8,
#          '추가': 8,
#          '여러': 8,
#          '김산': 8,
#          '기계': 8,
#          '주문': 8,
#          '특구': 8,
#          '취임': 8,
#          '안보': 8,
#          '유입': 7,
#          '미래': 7,
#          '징계': 7,
#          '점수': 7,
#          '군인': 7,
#          '이민': 7,
#          '조선업': 7,
#          '조선': 7,
#          '배출': 7,
#          '개정안': 7,
#          '전문가': 7,
#          '본부': 7,
#          '진출': 7,
#          '의욕': 7,
#          '카페': 7,
#          '웃음': 7,
#          '기': 7,
#          '도입': 7,
#          '예능': 7,
#          '제작발표회': 7,
#          '형': 7,
#          '일정': 7,
#          '신고': 7,
#          '교육부': 7,
#          '데브': 7,
#          '코스': 7,
#          '주니어': 7,
#          '개발자': 7,
#          '스': 7,
#          '기타': 7,
#          '요리': 7,
#          '때': 7,
#          '선배': 7,
#          '표': 7,
#          '부서': 7,
#          '청': 7,
#          '실제': 7,
#          '신동준': 7,
#          '차세대': 7,
#          '유플러스': 7,
#          '최유진': 7,
#          '고려대': 7,
#          '주행': 7,
#          '텍': 7,
#          '유광': 7,
#          '공주대': 7,
#          '동력': 7,
#          '유지': 7,
#          '보호관찰': 7,
#          '매출': 7,
#          '장려': 7,
#          '진학': 7,
#          '공급': 7,
#          '향후': 7,
#          '규모': 7,
#          '해소': 7,
#          '전담': 7,
#          '직장': 7,
#          '창의': 7,
#          '이해': 7,
#          '포함': 7,
#          '기후': 7,
#          '경쟁심': 7,
#          '월세': 7,
#          '안내': 7,
#          '포스': 7,
#          '티니': 7,
#          '리뉴얼': 7,
#          '교수': 7,
#          '거': 7,
#          '연장': 7,
#          '서초구': 7,
#          '협': 7,
#          '지자체': 7,
#          '중년': 7,
#          '서민': 7,
#          '증대': 7,
#          '부가가치': 7,
#          '토크': 7,
#          '콘서트': 7,
#          '부천': 7,
#          '류': 7,
#          '지역별': 7,
#          '사건': 7,
#          '선발': 6,
#          '이상인': 6,
#          '상황': 6,
#          '복무': 6,
#          '계고': 6,
#          '권오갑': 6,
#          '학자금대출': 6,
#          '임용': 6,
#          '신입': 6,
#          '강': 6,
#          '임종': 6,
#          '시립대': 6,
#          '얘기': 6,
#          '걸': 6,
#          '스쿨': 6,
#          '국적': 6,
#          '목동': 6,
#          '실전': 6,
#          '아동복지법': 6,
#          '치료감호': 6,
#          '선고': 6,
#          '확정': 6,
#          '혐의': 6,
#          '프로그래머': 6,
#          '대한민국': 6,
#          '급식': 6,
#          '영농': 6,
#          '폐기물': 6,
#          '한파': 6,
#          '실': 6,
#          '병실': 6,
#          '등지': 6,
#          '문답': 6,
#          '입': 6,
#          '퇴소': 6,
#          '북한': 6,
#          '이탈': 6,
#          '상생': 6,
#          '계약': 6,
#          '벚꽃': 6,
#          '중기': 6,
#          '뿐': 6,
#          '응용': 6,
#          '국가': 6,
#          '때문': 6,
#          '학부': 6,
#          '출연': 6,
#          '과장': 6,
#          '은둔': 6,
#          '현황': 6,
#          '한전': 6,
#          '특별': 6,
#          '공학': 6,
#          '연대': 6,
#          '논의': 6,
#          '짓': 6,
#          '일부': 6,
#          '출신': 6,
#          '수가': 6,
#          '소재': 6,
#          '체류': 6,
#          '구미대': 6,
#          '횡성군': 6,
#          '에너지': 6,
#          '행단': 6,
#          '동행': 6,
#          '녹색': 6,
#          '모든': 6,
#          '카리브': 6,
#          '발급': 6,
#          '부여': 6,
#          '이유': 6,
#          '학부모': 6,
#          '이야기': 6,
#          '글': 6,
#          '홍용준': 6,
#          '부문': 6,
#          '고객': 6,
#          '응원': 6,
#          '전환': 6,
#          '드림': 6,
#          '경고': 6,
#          '고등학교': 6,
#          '장애': 6,
#          '신설': 6,
#          '우석대': 6,
#          '강원': 6,
#          '의왕시': 6,
#          '불': 6,
#          '영진전문대': 6,
#          '대감': 5,
#          '주도': 5,
#          '코딩': 5,
#          '의무': 5,
#          '노동조합': 5,
#          '고령화': 5,
#          '위원회': 5,
#          '동안': 5,
#          '사실': 5,
#          '기능': 5,
#          '이해도': 5,
#          '이내': 5,
#          '이사장': 5,
#          '문턱': 5,
#          '앤': 5,
#          '속': 5,
#          '최종': 5,
#          '합격': 5,
#          '교': 5,
#          '자발': 5,
#          '가정': 5,
#          '간병인': 5,
#          '양': 5,
#          '창원': 5,
#          '극한': 5,
#          '매칭': 5,
#          '최다니엘': 5,
#          '가이드북': 5,
#          '업종': 5,
#          '장관': 5,
#          '옥천': 5,
#          '공지': 5,
#          '양식': 5,
#          '우편': 5,
#          '가이드': 5,
#          '당시': 5,
#          '문화재': 5,
#          '증진': 5,
#          '항공': 5,
#          '보호': 5,
#          '홀로': 5,
#          '아이': 5,
#          '인용': 5,
#          '수행': 5,
#          '장학': 5,
#          '건축': 5,
#          '간': 5,
#          '발생': 5,
#          '뉴스': 5,
#          '성인': 5,
#          '특화된': 5,
#          '안양시': 5,
#          '차지': 5,
#          '가운데': 5,
#          '작년': 5,
#          '접근': 5,
#          '특별자치도': 5,
#          '어기': 5,
#          '테': 5,
#          '게': 5,
#          '집중': 5,
#          '정주': 5,
#          '솔루션': 5,
#          '간소화': 5,
#          '수학': 5,
#          '우대': 5,
#          '범죄수사': 5,
#          '본래': 5,
#          '노동청': 5,
#          '별도': 5,
#          '소형': 5,
#          '지게차': 5,
#          '면허': 5,
#          '최초': 5,
#          '산': 5,
#          '자리': 5,
#          '구체': 5,
#          '공개': 5,
#          '심화': 5,
#          '컬': 5,
#          '동시': 5,
#          '환영': 5,
#          '실현': 5,
#          '고취': 5,
#          '동향': 5,
#          '최저': 5,
#          '대졸': 5,
#          '미술': 5,
#          '전시회': 5,
#          '단기간': 5,
#          '생계': 5,
#          '관광': 5,
#          '남도': 5,
#          '선착순': 5,
#          '피해자': 5,
#          '대응': 5,
#          '다음': 5,
#          '원주시': 5,
#          '의료': 5,
#          '방법': 5,
#          '추천': 5,
#          '대부분': 5,
#          '사후': 5,
#          '문책': 5,
#          '비중': 5,
#          '수원': 5,
#          '인천': 5,
#          '일대': 5,
#          '연간': 5,
#          '병합': 5,
#          '일선': 5,
#          '경찰서': 5,
#          '민정': 5,
#          '대화': 5,
#          '황현': 5,
#          '다자': 5,
#          '수출': 5,
#          '제주도': 5,
#          '반도체': 5,
#          ...})

# %%
# 임시 딕션너리에 담아서, 필요한 부분 추출해서 조사. 
word_count = dict()

# 상위 80개 정도 
for tag, counts in count.most_common(80):
  if(len(str(tag))>1):
    word_count[tag] = counts
    # print(f" tag : {tag}, counts : {counts}")
word_count
# Out:
# {'취업': 1653,
#  '청년': 521,
#  '지원': 374,
#  '지역': 343,
#  '준비': 225,
#  '사업': 221,
#  '교육': 194,
#  '위해': 161,
#  '경제': 155,
#  '일자리': 155,
#  '제공': 153,
#  '맞춤': 148,
#  '프로그램': 144,
#  '기업': 142,
#  '센터': 136,
#  '운영': 131,
#  '대학': 127,
#  '고용': 117,
#  '통해': 112,
#  '한국': 111,
#  '활동': 108,
#  '기관': 108,
#  '역량': 107,
#  '이번': 102,
#  '금융': 99,
#  '분야': 99,
#  '확대': 97,
#  '향상': 92,
#  '관련': 91,
#  '대상': 91,
#  '창업': 91,
#  '공인': 87,
#  '학생': 87,
#  '소상': 86,
#  '이상': 83,
#  '근로자': 80,
#  '구직': 74,
#  '노인': 71,
#  '사회': 71,
#  '채용': 70,
#  '안정': 69,
#  '진로': 69,
#  '외국인': 68,
#  '경남': 68,
#  '상담': 68,
#  '올해': 67,
#  '산업': 66,
#  '자녀': 63,
#  '추진': 63,
#  '장애인': 62,
#  '한편': 61,
#  '시설': 61,
#  '활성화': 60,
#  '목표': 60,
#  '주택': 60,
#  '효과': 59,
#  '주거': 59,
#  '김해': 58,
#  '기여': 58,
#  '신규': 57}

# %%
# 시각화1, 막대 그래프 
# 폰트 임포트 , 메모리에 설정 
font_path = "c:/Windows/Fonts/malgunbd.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rc("font", family = font_name)

#, x축, y축, 가로x세로 비율, x 라벨, 폰트 설정 등
plt.figure(figsize=(12,6))
plt.xlabel("키워드")
plt.ylabel("빈도수")
plt.grid(True)

# 딕션너리의 키, 값 , 정렬 내림차순 
sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(),reverse=True)

# 막대 그래프 그리기. 
plt.bar(range(len(word_count)), sorted_Values, align="center")

# x 축 라벨 설정. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# !pip install Numpy

# %%
# 시각화2, 워드 클라우드 
import numpy as np

import os
import re
from PIL import Image
from os import path

alice_mask = np.array(Image.open("dog_image4_test.png"))

# 실행시, 한글이 깨져서, 해당 폰트 패스 경로 지정 필요.
wc = WordCloud(font_path, background_color="white", max_words=1000, mask=alice_mask,width=800,height=1000)
# generate word cloud
sampleImage = wc.generate_from_frequencies(word_count)

# show
plt.imshow(sampleImage, interpolation="bilinear")
# plt.imshow(sampleImage)

plt.axis("off")
plt.show()

# %%
# 해당 출력을 이미지로 저장 하기. 
sampleImage.to_file(inputFileName + "_cloud.jpg")
